# %% [markdown]
# ## Question 4
# ---------
# Faites une analyse détaillée et exhaustive des patrons existants dans le jeu de données adulte.
# Il est possible que le regroupement de valeurs pour certaines caractéristiques donne des résultat intéressant.
# Vous devez aussi, s’il y a lieux, discuter de l’aspect éthique concernant l’utilisation des patrons obtenus.

# %%
# %matplotlib inline
import csv
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
i=0
j=0

data = open('adult.csv') 
reader = csv.reader(data)

dataSet=[] 
for row in reader:            
    dataSet.append(row)

print(len(dataSet))
def fonctionTb(k):
    
    datacompl2= []
    for k in range(k,k+1):
        for i in range(0,1):
    
            for j in range(0,15):
                age=dataSet[0][j]
                colonne=dataSet[k][j]
                donnee= age +':'+ colonne
                
                datacompl2.append(donnee)
                
    return datacompl2
dataClean= []
for l in range (len(dataSet)):
    resultat = fonctionTb(l)

    dataClean.append(resultat)

dataClean.pop(0)
data.close()
#print(dataClean)
# Out:
# 48843

# %%
# cette fonction prends une liste C1, la trier, mapper chaque élément de la liste sur frozenset () 
#et renvoyez cette liste de frozensets.
def createC1(dataClean):
    C1 = []
    for transaction in dataClean:
        for item in transaction:
            if not [item] in C1:
                C1.append([item])
                
    #C1.sort()
    return list(map(frozenset, C1))#utilise un ensemble figé pour pouvoir l'utiliser comme clé dans un dictionnaire

# %%
C1 = createC1(dataClean)

#print(C1)

# %%
D = list(map(set,dataClean))
D
# Out:
# [{'age:25',
#   'capital-gain:0',
#   'capital-loss:0',
#   'education:11th',
#   'educational-num:7',
#   'fnlwgt:226802',
#   'gender:Male',
#   'hours-per-week:40',
#   'income:<=50K',
#   'marital-status:Never-married',
#   'native-country:United-States',
#   'occupation:Machine-op-inspct',
#   'race:Black',
#   'relationship:Own-child',
#   'workclass:Private'},
#  {'age:38',
#   'capital-gain:0',
#   'capital-loss:0',
#   'education:HS-grad',
#   'educational-num:9',
#   'fnlwgt:89814',
#   'gender:Male',
#   'hours-per-week:50',
#   'income:<=50K',
#   'marital-status:Married-civ-spouse',
#   'native-country:United-States',
#   'occupation:Farming-fishing',
#   'race:White',
#   'relationship:Husband',
#   'workclass:Private'},
#  {'age:28',
#   'capital-gain:0',
#   'capital-loss:0',
#   'education:Assoc-acdm',
#   'educational-num:12',
#   'fnlwgt:336951',
#   'gender:Male',
#   'hours-per-week:40',
#   'income:>50K',
#   'marital-status:Married-civ-spouse',
# ...

# %%
#Cette fonction prend trois arguments: un ensemble de données, Ck, une liste d'ensembles candidats et un support min, 
#qui est le support minimum qui vous intéresse. Cette fonction est utilisée pour générer L1 à partir de C1. 
#De plus, cette fonction retourne un dictionnaire avec des valeurs de support.
#C1 est un groupe d’éléments candidat de taille 1. Dans l'algorithme Apriori, nous créons C1, puis nous analysons 
#l'ensemble de données pour voir si ces ensembles d'éléments répondent à nos exigences de support minimales. 
#Les ensembles d'éléments qui répondent à nos exigences minimales deviennent L1. 
#L1 est ensuite combiné pour devenir C2 et C2 sera filtré pour devenir L2.
def scanD(D, Ck, minSupport):
    ssCnt = {}
    for tid in D:
        for can in Ck:
            if can.issubset(tid):
                if not can in ssCnt: ssCnt[can]=1
                else: ssCnt[can] += 1
    numItems = float(len(D))
    retList = []
    supportData = {}
    for key in ssCnt:
        support = ssCnt[key]/numItems
        if support >= minSupport:
            retList.insert(0,key)
        supportData[key] = support
    return retList, supportData

# %%
L1,suppDat0 = scanD(D,C1,0.5)
L1
# Out:
# [frozenset({'race:White'}),
#  frozenset({'income:<=50K'}),
#  frozenset({'native-country:United-States'}),
#  frozenset({'capital-loss:0'}),
#  frozenset({'capital-gain:0'}),
#  frozenset({'gender:Male'}),
#  frozenset({'workclass:Private'})]

# %%
#La fonction aprioriGen () prendra une liste d'itemsets fréquents, Lk, et la taille des itemsets,
#k, pour produire Ck. Par exemple, les itemsets {0}, {1}, {2} et ainsi de suite seront générés {0,1} {0,2} et {1,2}.
def aprioriGen(Lk, k): #Creer Ck
    retList = []
    lenLk = len(Lk)
    for i in range(lenLk):
        for j in range(i+1, lenLk): 
            L1 = list(Lk[i])[:k-2]; L2 = list(Lk[j])[:k-2]
            L1.sort(); L2.sort()
            if L1==L2: #si k-2 premier elements sont egaux
                retList.append(Lk[i] | Lk[j]) #ajouter ensemble union
    return retList

# %%
def apriori(dataClean, minSupport = 0.5):
    C1 = createC1(dataClean)
    D = list(map(set, dataClean))
    L1, supportData = scanD(D, C1, minSupport)
    L = [L1]
    k = 2
    while (len(L[k-2]) > 0):
        Ck = aprioriGen(L[k-2], k)
        Lk, supK = scanD(D, Ck, minSupport)#balayer DB pour obtenir Lk
        supportData.update(supK)
        L.append(Lk)
        k += 1
    return L, supportData #L contient des listes de jeux d'éléments fréquents qui ont rencontré un support minimum de 0.5. 
                          #La variable suppData est un dictionnaire avec les valeurs de support de nos itemsets

# %%
#La fonction generateRules () prend trois entrées: une liste d'ensembles d'éléments fréquents, 
#un dictionnaire de données de support pour ces ensembles d'éléments et un seuil de confiance minimal. 
#Il va générer une liste de règles avec des valeurs de confiance que nous pourrons trier plus tard.
def generateRules(L, supportData, minConf=0.7):  #supportData est un dictionnaire qui vient de la fonction scanD 
    bigRuleList = []
    for i in range(1, len(L)):#n'obtenez que les ensembles contenant deux objets ou plus
        for freqSet in L[i]:
            H1 = [frozenset([item]) for item in freqSet]
            if (i > 1):
                rulesFromConseq(freqSet, H1, supportData, bigRuleList, minConf)
            else:
                calcConf(freqSet, H1, supportData, bigRuleList, minConf)
    return bigRuleList  

def calcConf(freqSet, H, supportData, brl, minConf=0.7):
    # H: items individuels dans le jeu d'associations 
    # brl:la grande liste de règles à modifier
    prunedH = []
    for conseq in H:
        conf = supportData[freqSet]/supportData[freqSet-conseq]
        if conf >= minConf:
            print (freqSet-conseq,'-->',conseq,'conf:',conf)
            brl.append((freqSet-conseq, conseq, conf))
            prunedH.append(conseq)
    return prunedH

def rulesFromConseq(freqSet, H, supportData, brl, minConf=0.7):
    m = len(H[0])
    if (len(freqSet) > (m + 1)):
        Hmp1 = aprioriGen(H, m + 1)
        Hmp1 = calcConf(freqSet, Hmp1, supportData, brl, minConf)
        if (len(Hmp1) > 1):
            rulesFromConseq(freqSet, Hmp1, supportData, brl, minConf)

# %%
L,suppData = apriori(dataClean)

# %%
rules= generateRules(L,suppData, minConf=0.7)
# Out:
# frozenset({'workclass:Private'}) --> frozenset({'race:White'}) conf: 0.8560136848935291
# frozenset({'gender:Male'}) --> frozenset({'race:White'}) conf: 0.8800918836140889
# frozenset({'capital-gain:0'}) --> frozenset({'race:White'}) conf: 0.8521882741535921
# frozenset({'race:White'}) --> frozenset({'capital-gain:0'}) conf: 0.9143240266270772
# frozenset({'capital-loss:0'}) --> frozenset({'race:White'}) conf: 0.85356529209622
# frozenset({'race:White'}) --> frozenset({'capital-loss:0'}) conf: 0.9516306690292611
# frozenset({'native-country:United-States'}) --> frozenset({'race:White'}) conf: 0.8781940135061143
# frozenset({'race:White'}) --> frozenset({'native-country:United-States'}) conf: 0.9217230975527992
# frozenset({'income:<=50K'}) --> frozenset({'race:White'}) conf: 0.838514331853048
# frozenset({'race:White'}) --> frozenset({'income:<=50K'}) conf: 0.7460131219769168
# frozenset({'workclass:Private'}) --> frozenset({'capital-gain:0'}) conf: 0.9239072730490178
# ...

# %% [markdown]
# Voici les patrons trouvés avec les differentes règles d'associations trouvées, accompagnées de leurs niveau de
# confiance chacun.
# {} ----> {} signifie que si on a trouvé des caracteristiques appartenant a un adulte dans la premiere accolade
# il est probable à une certaine niveau de confiance d'en trouver les caracteristiques qui suivent dans la seconde accolade.
# D'après nos études après avoir etudié toutes nos règles d'associations trouvées.
# on peut conclure que :
#      la plupart des adultes que son 'capital-gain:0', son 'capital-loss:0' et qui a un revenu 'income:<=50K'
#      sont de 'native-country:United-States' et de 'race:White', et viennent de 'workclass:Private'.
#
# On peut dire que du coté d'étique on remaque il y a une grande inégalité sociale entre les adultes surtout dans la race et
# la classe de travail.
# Du coté de la confidnetialité des donnees concernant d'un adulte les patrons trouvés ne fournissent pas assez d'informations pour savoir le nom de cet adulte en particulier. On pense que c'est une très bonne chose en parlant d'étique.

# %% [raw]
# {'workclass:Private'} --> {'race:White'} conf: 0.8560136848935291
# {'gender:Male'} --> {'race:White'} conf: 0.8800918836140889
# {'capital-gain:0'} --> {'race:White'} conf: 0.8521882741535921
# {'race:White'}) --> {'capital-gain:0'}) conf: 0.9143240266270772
# {'capital-loss:0'}) --> {'race:White'}) conf: 0.85356529209622
# {'race:White'}) --> {'capital-loss:0'}) conf: 0.9516306690292611
# {'native-country:United-States'}) --> {'race:White'}) conf: 0.8781940135061143
# {'race:White'}) --> {'native-country:United-States'}) conf: 0.9217230975527992
# {'income:<=50K'}) --> {'race:White'}) conf: 0.838514331853048
# {'race:White'}) --> {'income:<=50K'}) conf: 0.7460131219769168
# {'workclass:Private'}) --> {'capital-gain:0'}) conf: 0.9239072730490178
# {'gender:Male'}) --> {'capital-gain:0'}) conf: 0.9051454823889741
# {'workclass:Private'}) --> {'capital-loss:0'}) conf: 0.9564973750958532
# {'gender:Male'}) --> {'capital-loss:0'}) conf: 0.9470750382848392
# {'capital-loss:0'}) --> {'capital-gain:0'}) conf: 0.9133376288659794
# {'capital-gain:0'}) --> {'capital-loss:0'}) conf: 0.949070457740978
# {'workclass:Private'}) --> {'native-country:United-States'}) conf: 0.8890756798206807
# {'gender:Male'}) --> {'native-country:United-States'}) conf: 0.8950382848392038
# {'native-country:United-States'}) --> {'capital-gain:0'}) conf: 0.915906187260449
# {'capital-gain:0'}) --> {'native-country:United-States'}) conf: 0.8959760751668266
# {'native-country:United-States'}) --> {'capital-loss:0'}) conf: 0.9525460850520168
# {'capital-loss:0'}) --> {'native-country:United-States'}) conf: 0.8967353951890035
# {'income:<=50K'}) --> {'workclass:Private'}) conf: 0.7137397389315031
# {'workclass:Private'}) --> {'income:<=50K'}) conf: 0.782132955819029
# {'income:<=50K'}) --> {'capital-gain:0'}) conf: 0.9584443547301843
# {'capital-gain:0'}) --> {'income:<=50K'}) conf: 0.794764210949182
# {'income:<=50K'}) --> {'capital-loss:0'}) conf: 0.969371551608128
# {'capital-loss:0'}) --> {'income:<=50K'}) conf: 0.7735609965635739
# {'income:<=50K'}) --> {'native-country:United-States'}) conf: 0.8918853451756156
# {'native-country:United-States'}) --> {'income:<=50K'}) conf: 0.756022996897244
# {'income:<=50K'}) --> {'race:White', 'native-country:United-States'}) conf: 0.7670838379760462
# {'income:<=50K'}) --> {'race:White', 'capital-loss:0'}) conf: 0.8122729107791683
# {'race:White'}) --> {'capital-loss:0', 'income:<=50K'}) conf: 0.7226665389588621
# {'capital-loss:0'}) --> {'race:White', 'native-country:United-States'}) conf: 0.7857603092783505
# {'race:White'}) --> {'capital-loss:0', 'native-country:United-States'}) conf: 0.8760356304774675
# {'native-country:United-States'}) --> {'race:White', 'capital-loss:0'}) conf: 0.8346641722942142
# {'income:<=50K'}) --> {'race:White', 'capital-gain:0'}) conf: 0.8027183420804735
# {'race:White'}) --> {'capital-gain:0', 'income:<=50K'}) conf: 0.7141659882189549
# {'native-country:United-States'}) --> {'race:White', 'capital-gain:0'}) conf: 0.8016973900346779
# {'capital-gain:0'}) --> {'race:White', 'native-country:United-States'}) conf: 0.7842524605530387
# {'race:White'}) --> {'capital-gain:0', 'native-country:United-States'}) conf: 0.8414347971840429
# {'capital-loss:0'}) --> {'race:White', 'capital-gain:0'}) conf: 0.7767182130584193
# {'capital-gain:0'}) --> {'race:White', 'capital-loss:0'}) conf: 0.8071060325395586
# {'race:White'}) --> {'capital-gain:0', 'capital-loss:0'}) conf: 0.8659546956563383
# {'gender:Male'}) --> {'race:White', 'native-country:United-States'}) conf: 0.8101071975497703
# {'gender:Male'}) --> {'race:White', 'capital-loss:0'}) conf: 0.8323736600306278
# {'gender:Male'}) --> {'race:White', 'capital-gain:0'}) conf: 0.7947932618683001
# {'workclass:Private'}) --> {'race:White', 'native-country:United-States'}) conf: 0.782752315224444
# {'workclass:Private'}) --> {'race:White', 'capital-loss:0'}) conf: 0.8174659352327022
# {'workclass:Private'}) --> {'race:White', 'capital-gain:0'}) conf: 0.7882970565681591
# {'income:<=50K'}) --> {'native-country:United-States', 'capital-loss:0'}) conf: 0.8641367245323643
# {'native-country:United-States'}) --> frozenset({'capital-loss:0', 'income:<=50K'}) conf: 0.7325013688629312
# {'income:<=50K'}) --> frozenset({'capital-gain:0', 'native-country:United-States'}) conf: 0.8542322702193513
# {'native-country:United-States'}) --> frozenset({'capital-gain:0', 'income:<=50K'}) conf: 0.724105676218288
# {'capital-gain:0'}) --> frozenset({'native-country:United-States', 'income:<=50K'}) conf: 0.7083491418751534
# {'income:<=50K'}) --> frozenset({'capital-gain:0', 'capital-loss:0'}) conf: 0.9278159063383125
# {'capital-loss:0'}) --> frozenset({'capital-gain:0', 'income:<=50K'}) conf: 0.7403994845360825
# {'capital-gain:0'}) --> frozenset({'capital-loss:0', 'income:<=50K'}) conf: 0.7693663936438503
# {'capital-loss:0'}) --> frozenset({'capital-gain:0', 'native-country:United-States'}) conf: 0.8175687285223369
# {'capital-gain:0'}) --> frozenset({'capital-loss:0', 'native-country:United-States'}) conf: 0.849554757069208
# {'native-country:United-States'}) --> frozenset({'capital-gain:0', 'capital-loss:0'}) conf: 0.8684522723124658
# {'gender:Male'}) --> {'capital-loss:0', 'native-country:United-States'}) conf: 0.8468912710566616
# {'workclass:Private'}) --> {'capital-loss:0', 'income:<=50K'}) conf: 0.7596885506989913
# {'workclass:Private'}) --> {'capital-loss:0', 'native-country:United-States'}) conf: 0.849495664484162
# {'gender:Male'}) --> {'capital-gain:0', 'native-country:United-States'}) conf: 0.808698315467075
# {'gender:Male'}) --> {'capital-gain:0', 'capital-loss:0'}) conf: 0.8522205206738133
# {'workclass:Private'}) --> {'capital-gain:0', 'income:<=50K'}) conf: 0.7514009319884387
# {'workclass:Private'}) --> {'capital-gain:0', 'native-country:United-States'}) conf: 0.8195894531941249
# {'workclass:Private'}) --> {'capital-gain:0', 'capital-loss:0'}) conf: 0.8804046481448711
# {'gender:Male', 'native-country:United-States'}) --> {'race:White', 'capital-loss:0'}) conf: 0.8546692673579029
# {'gender:Male', 'race:White'}) --> {'native-country:United-States', 'capital-loss:0'}) conf: 0.869183922046285
# {'gender:Male', 'capital-loss:0'}) --> ({'race:White', 'native-country:United-States'}) conf: 0.8077097212340729
# {'gender:Male'}) --> {'native-country:United-States', 'race:White', 'capital-loss:0'}) conf: 0.7649617151607964
# {'race:White', 'workclass:Private'}) --> {'capital-gain:0', 'capital-loss:0'}) conf: 0.8758613561190738
# {'capital-loss:0', 'workclass:Private'}) --> {'race:White', 'capital-gain:0'}) conf: 0.7838487866547439
# {'capital-gain:0', 'workclass:Private'}) --> {'race:White', 'capital-loss:0'}) conf: 0.8114984358041244
# {'workclass:Private'}) --> {'race:White', 'capital-gain:0', 'capital-loss:0'}) conf: 0.749749306907332
# {'race:White', 'native-country:United-States'}) --> {'capital-gain:0', 'capital-loss:0'}) conf: 0.8633257994960123
# {'native-country:United-States', 'capital-loss:0'}) --> {'race:White', 'capital-gain:0'}) conf: 0.7959379191415981
# {'race:White', 'capital-loss:0'}) --> {'capital-gain:0', 'native-country:United-States'}) conf: 0.8361934477379095
# {'capital-gain:0', 'native-country:United-States'}) --> {'race:White', 'capital-loss:0'}) conf: 0.8277786080805062
# {'race:White', 'capital-gain:0'}) --> {'native-country:United-States', 'capital-loss:0'}) conf: 0.8703121726377541
# {'capital-gain:0', 'capital-loss:0'}) --> {'race:White', 'native-country:United-States'}) conf: 0.781469723691946
# {'race:White'}) --> {'native-country:United-States', 'capital-gain:0', 'capital-loss:0'}) conf: 0.7957473301087113
# {'native-country:United-States'}) --> {'race:White', 'capital-gain:0', 'capital-loss:0'}) conf: 0.7581675488227779
# {'capital-loss:0'}) --> {'race:White', 'capital-gain:0', 'native-country:United-States'}) conf: 0.713745704467354
# {'capital-gain:0'}) --> {'native-country:United-States', 'race:White', 'capital-loss:0'}) conf: 0.7416698283750307
# {'race:White', 'income:<=50K'}) --> {'capital-gain:0', 'capital-loss:0'}) conf: 0.9260150858610174
# {'capital-loss:0', 'income:<=50K'}) --> {'race:White', 'capital-gain:0'}) conf: 0.8010106338673404
# {'race:White', 'capital-loss:0'}) --> {'capital-gain:0', 'income:<=50K'}) conf: 0.7259322630969754
# {'capital-gain:0', 'income:<=50K'}) --> {'race:White', 'capital-loss:0'}) conf: 0.8101429333632866
# {'race:White', 'capital-gain:0'}) --> {'capital-loss:0', 'income:<=50K'}) conf: 0.7555520636915986
# {'income:<=50K'}) --> frozenset({'race:White', 'capital-gain:0', 'capital-loss:0'}) conf: 0.7764769210065939
# {'native-country:United-States', 'income:<=50K'}) --> frozenset({'race:White', 'capital-gain:0'}) conf: 0.823012855332247
# {'race:White', 'income:<=50K'}) --> {'capital-gain:0', 'native-country:United-States'}) conf: 0.8753972075108329
# {'race:White', 'native-country:United-States'}) --> {'capital-gain:0', 'income:<=50K'}) conf: 0.7085184319226872
# {'capital-gain:0', 'income:<=50K'}) --> {'race:White', 'native-country:United-States'}) conf: 0.7658588638342085
# {'race:White', 'capital-gain:0'}) --> {'native-country:United-States', 'income:<=50K'}) conf: 0.7142520427404149
# {'income:<=50K'}) --> {'race:White', 'capital-gain:0', 'native-country:United-States'}) conf: 0.73403310456197
# {'native-country:United-States', 'workclass:Private'}) --> {'race:White', 'capital-loss:0'}) conf: 0.8395090396417315
# {'race:White', 'workclass:Private'}) --> {'native-country:United-States', 'capital-loss:0'}) conf: 0.8719335722160969
# {'capital-loss:0', 'workclass:Private'}) --> {'race:White', 'native-country:United-States'}) conf: 0.7803336314020536
# {'workclass:Private'}) --> {'native-country:United-States', 'race:White', 'capital-loss:0'}) conf: 0.7463870701350793
# {'native-country:United-States', 'income:<=50K'}) --> {'race:White', 'capital-loss:0'}) conf: 0.8324582050817793
# {'race:White', 'income:<=50K'}) --> {'native-country:United-States', 'capital-loss:0'}) conf: 0.8854437489969508
# {'race:White', 'native-country:United-States'}) --> {'capital-loss:0', 'income:<=50K'}) conf: 0.7166497804795677
# {'capital-loss:0', 'income:<=50K'}) --> {'race:White', 'native-country:United-States'}) conf: 0.7659160951772774
# {'income:<=50K'}) --> {'native-country:United-States', 'race:White', 'capital-loss:0'}) conf: 0.7424572735836361
# {'gender:Male', 'native-country:United-States'}) --> {'capital-gain:0', 'capital-loss:0'}) conf: 0.849741641857441
# {'gender:Male', 'capital-loss:0'}) --> {'capital-gain:0', 'native-country:United-States'}) conf: 0.8030528426363108
# {'gender:Male', 'capital-gain:0'}) --> {'native-country:United-States', 'capital-loss:0'}) conf: 0.8402531045917505
# {'gender:Male'}) --> {'native-country:United-States', 'capital-gain:0', 'capital-loss:0'}) conf: 0.760551301684533
# {'native-country:United-States', 'workclass:Private'}) --> {'capital-gain:0', 'capital-loss:0'}) conf: 0.8773262564272682
# {'capital-loss:0', 'workclass:Private'}) --> {'capital-gain:0', 'native-country:United-States'}) conf: 0.815485183928957
# {'capital-gain:0', 'workclass:Private'}) --> {'native-country:United-States', 'capital-loss:0'}) conf: 0.8442507820979379
# {'workclass:Private'}) --> {'native-country:United-States', 'capital-gain:0', 'capital-loss:0'}) conf: 0.7800094378576063
# {'income:<=50K', 'workclass:Private'}) --> {'capital-gain:0', 'capital-loss:0'}) conf: 0.9320110109732644
# {'capital-loss:0', 'workclass:Private'}) --> {'capital-gain:0', 'income:<=50K'}) conf: 0.7621103265394221
# {'capital-gain:0', 'workclass:Private'}) --> {'capital-loss:0', 'income:<=50K'}) conf: 0.7889931686139309
# {'workclass:Private'}) --> {'capital-gain:0', 'capital-loss:0', 'income:<=50K'}) conf: 0.7289565268684008
# {'native-country:United-States', 'income:<=50K'}) --> {'capital-gain:0', 'capital-loss:0'}) conf: 0.9266702878870179
# {'capital-loss:0', 'income:<=50K'}) --> {'capital-gain:0', 'native-country:United-States'}) conf: 0.8525973845683983
# {'native-country:United-States', 'capital-loss:0'}) --> {'capital-gain:0', 'income:<=50K'}) conf: 0.7354857252347192
# {'capital-gain:0', 'income:<=50K'} --> {'native-country:United-States', 'capital-loss:0'}) conf: 0.862317823144534
# {'capital-gain:0', 'native-country:United-States'} --> {'capital-loss:0', 'income:<=50K'}) conf: 0.7649080854879688
# {'capital-gain:0', 'capital-loss:0'}) --> frozenset({'native-country:United-States', 'income:<=50K'}) conf: 0.722116402116402
# {'income:<=50K'}) --> frozenset({'native-country:United-States', 'capital-gain:0', 'capital-loss:0'}) conf: 0.8264836495761
# {'native-country:United-States'}) --> frozenset({'capital-gain:0', 'capital-loss:0', 'income:<=50K'})  conf:0.7005840481839751
# {'race:White', 'capital-loss:0', 'income:<=50K'}) --> frozenset({'capital-gain:0', 'native-country:United-States'}) conf: 0.8733598409542743
# {'race:White', 'native-country:United-States', 'income:<=50K'}) --> frozenset({'capital-gain:0', 'capital-loss:0'}) conf: 0.924809655801551
# {'capital-loss:0', 'native-country:United-States', 'income:<=50K'}) --> frozenset({'race:White', 'capital-gain:0'}) conf: 0.8209424736038872
# {'capital-loss:0', 'race:White', 'native-country:United-States'}) --> frozenset({'capital-gain:0', 'income:<=50K'}) conf: 0.720459204592046
# {'race:White', 'capital-gain:0', 'income:<=50K'}) --> frozenset({'capital-loss:0', 'native-country:United-States'}) conf: 0.8837552388935458
# {'capital-gain:0', 'capital-loss:0', 'income:<=50K'}) --> frozenset({'race:White', 'native-country:United-States'}) conf: 0.7645983813419198
# {'race:White', 'capital-gain:0', 'capital-loss:0'}) --> frozenset({'native-country:United-States', 'income:<=50K'}) conf: 0.7288463665523726
# {'capital-gain:0', 'native-country:United-States', 'income:<=50K'}) --> frozenset({'race:White', 'capital-loss:0'}) conf: 0.8304609470997827
# {'race:White', 'capital-gain:0', 'native-country:United-States'}) --> frozenset({'capital-loss:0', 'income:<=50K'}) conf: 0.7500853727945361
# {'race:White', 'income:<=50K'}) --> frozenset({'capital-loss:0', 'capital-gain:0', 'native-country:United-States'}) conf: 0.8460279248916708
# {'capital-loss:0', 'income:<=50K'}) --> frozenset({'race:White', 'capital-gain:0', 'native-country:United-States'}) conf: 0.7318210844878809
# {'native-country:United-States', 'income:<=50K'}) --> frozenset({'race:White', 'capital-gain:0', 'capital-loss:0'}) conf: 0.795401050153902
# {'capital-gain:0', 'income:<=50K'}) --> frozenset({'capital-loss:0', 'race:White', 'native-country:United-States'}) conf: 0.7401645558956503
# {'income:<=50K'}) --> frozenset({'capital-gain:0', 'capital-loss:0', 'race:White', 'native-country:United-States'}) conf: 0.70940654016956
