# %% [markdown]
# ## Question 4
# ---------
# Faites une analyse détaillée et exhaustive des patrons existants dans le jeu de données adulte.
# Il est possible que le regroupement de valeurs pour certaines caractéristiques donne des résultat intéressant.
# Vous devez aussi, s’il y a lieux, discuter de l’aspect éthique concernant l’utilisation des patrons obtenus.

# %%
# %matplotlib inline
import csv
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
dataSet= []
idx = 0

with open('adult.csv') as csv_file:
    reader = csv.reader(csv_file, delimiter=' ')
    for i, row in enumerate(reader):            
        dataSet.append(row[:-1])

# %%
# cette fonction prends une liste C1, la trier, mapper chaque élément de la liste sur frozenset () 
#et renvoyez cette liste de frozensets.
def createC1(dataSet):
    C1 = []
    for transaction in dataSet:
        for item in transaction:
            if not [item] in C1:
                C1.append([item])
                
    C1.sort()
    return list(map(frozenset, C1))#utilise un ensemble figé pour pouvoir l'utiliser comme clé dans un dictionnaire

# %%
C1 = createC1(dataSet)

# %%
D = list(map(set,dataSet))

# %%
D
# Out:
# [{'Age,',
#   'capital-gain,',
#   'capital-loss,',
#   'education,',
#   'education-num,',
#   'fnlwgt,',
#   'hours-per-week,',
#   'marital-status,',
#   'native-country,',
#   'occupation,',
#   'race,',
#   'relationship,',
#   'sex,',
#   'workclass,'},
#  {'0,',
#   '13,',
#   '2174,',
#   '39,',
#   '40,',
#   '77516,',
#   'Adm-clerical,',
#   'Bachelors,',
#   'Male,',
#   'Never-married,',
#   'Not-in-family,',
#   'State-gov,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '13,',
#   '50,',
#   '83311,',
#   'Bachelors,',
#   'Exec-managerial,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Self-emp-not-inc,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '215646,',
#   '38,',
#   '40,',
#   '9,',
#   'Divorced,',
#   'HS-grad,',
#   'Handlers-cleaners,',
#   'Male,',
#   'Not-in-family,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '11th,',
#   '234721,',
#   '40,',
#   '53,',
#   '7,',
#   'Black,',
#   'Handlers-cleaners,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'United-States,'},
#  {'0,',
#   '13,',
#   '28,',
#   '338409,',
#   '40,',
#   'Bachelors,',
#   'Black,',
#   'Cuba,',
#   'Female,',
#   'Married-civ-spouse,',
#   'Private,',
#   'Prof-specialty,',
#   'Wife,'},
#  {'0,',
#   '14,',
#   '284582,',
#   '37,',
#   '40,',
#   'Exec-managerial,',
#   'Female,',
#   'Married-civ-spouse,',
#   'Masters,',
#   'Private,',
#   'United-States,',
#   'White,',
#   'Wife,'},
#  {'0,',
#   '16,',
#   '160187,',
#   '49,',
#   '5,',
#   '9th,',
#   'Black,',
#   'Female,',
#   'Jamaica,',
#   'Married-spouse-absent,',
#   'Not-in-family,',
#   'Other-service,',
#   'Private,'},
#  {'0,',
#   '209642,',
#   '45,',
#   '52,',
#   '9,',
#   'Exec-managerial,',
#   'HS-grad,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Self-emp-not-inc,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '14,',
#   '14084,',
#   '31,',
#   '45781,',
#   '50,',
#   'Female,',
#   'Masters,',
#   'Never-married,',
#   'Not-in-family,',
#   'Private,',
#   'Prof-specialty,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '13,',
#   '159449,',
#   '40,',
#   '42,',
#   '5178,',
#   'Bachelors,',
#   'Exec-managerial,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '280464,',
#   '37,',
#   '80,',
#   'Black,',
#   'Exec-managerial,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'Some-college,',
#   'United-States,'},
#  {'0,',
#   '13,',
#   '141297,',
#   '30,',
#   '40,',
#   'Asian-Pac-Islander,',
#   'Bachelors,',
#   'Husband,',
#   'India,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Prof-specialty,',
#   'State-gov,'},
#  {'0,',
#   '122272,',
#   '13,',
#   '23,',
#   '30,',
#   'Adm-clerical,',
#   'Bachelors,',
#   'Female,',
#   'Never-married,',
#   'Own-child,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '12,',
#   '205019,',
#   '32,',
#   '50,',
#   'Assoc-acdm,',
#   'Black,',
#   'Male,',
#   'Never-married,',
#   'Not-in-family,',
#   'Private,',
#   'Sales,',
#   'United-States,'},
#  {'0,',
#   '11,',
#   '121772,',
#   '40,',
#   '40,?,',
#   'Asian-Pac-Islander,',
#   'Assoc-voc,',
#   'Craft-repair,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,'},
#  {'0,',
#   '245487,',
#   '34,',
#   '4,',
#   '45,',
#   '7th-8th,',
#   'Amer-Indian-Eskimo,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Mexico,',
#   'Private,',
#   'Transport-moving,'},
#  {'0,',
#   '176756,',
#   '25,',
#   '35,',
#   '9,',
#   'Farming-fishing,',
#   'HS-grad,',
#   'Male,',
#   'Never-married,',
#   'Own-child,',
#   'Self-emp-not-inc,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '186824,',
#   '32,',
#   '40,',
#   '9,',
#   'HS-grad,',
#   'Machine-op-inspct,',
#   'Male,',
#   'Never-married,',
#   'Private,',
#   'United-States,',
#   'Unmarried,',
#   'White,'},
#  {'0,',
#   '11th,',
#   '28887,',
#   '38,',
#   '50,',
#   '7,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'Sales,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '14,',
#   '292175,',
#   '43,',
#   '45,',
#   'Divorced,',
#   'Exec-managerial,',
#   'Female,',
#   'Masters,',
#   'Self-emp-not-inc,',
#   'United-States,',
#   'Unmarried,',
#   'White,'},
#  {'0,',
#   '16,',
#   '193524,',
#   '40,',
#   '60,',
#   'Doctorate,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'Prof-specialty,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '20,',
#   '302146,',
#   '54,',
#   '9,',
#   'Black,',
#   'Female,',
#   'HS-grad,',
#   'Other-service,',
#   'Private,',
#   'Separated,',
#   'United-States,',
#   'Unmarried,'},
#  {'0,',
#   '35,',
#   '40,',
#   '5,',
#   '76845,',
#   '9th,',
#   'Black,',
#   'Farming-fishing,',
#   'Federal-gov,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'United-States,'},
#  {'0,',
#   '117037,',
#   '11th,',
#   '2042,',
#   '40,',
#   '43,',
#   '7,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'Transport-moving,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '109015,',
#   '40,',
#   '59,',
#   '9,',
#   'Divorced,',
#   'Female,',
#   'HS-grad,',
#   'Private,',
#   'Tech-support,',
#   'United-States,',
#   'Unmarried,',
#   'White,'},
#  {'0,',
#   '13,',
#   '216851,',
#   '40,',
#   '56,',
#   'Bachelors,',
#   'Husband,',
#   'Local-gov,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Tech-support,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '168294,',
#   '19,',
#   '40,',
#   '9,',
#   'Craft-repair,',
#   'HS-grad,',
#   'Male,',
#   'Never-married,',
#   'Own-child,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '180211,',
#   '54,?,',
#   '60,',
#   'Asian-Pac-Islander,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,?,',
#   'Some-college,',
#   'South,'},
#  {'0,',
#   '367260,',
#   '39,',
#   '80,',
#   '9,',
#   'Divorced,',
#   'Exec-managerial,',
#   'HS-grad,',
#   'Male,',
#   'Not-in-family,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '193366,',
#   '40,',
#   '49,',
#   '9,',
#   'Craft-repair,',
#   'HS-grad,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '12,',
#   '190709,',
#   '23,',
#   '52,',
#   'Assoc-acdm,',
#   'Local-gov,',
#   'Male,',
#   'Never-married,',
#   'Not-in-family,',
#   'Protective-serv,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '20,',
#   '266015,',
#   '44,',
#   'Black,',
#   'Male,',
#   'Never-married,',
#   'Own-child,',
#   'Private,',
#   'Sales,',
#   'Some-college,',
#   'United-States,'},
#  {'0,',
#   '13,',
#   '1408,',
#   '386940,',
#   '40,',
#   '45,',
#   'Bachelors,',
#   'Divorced,',
#   'Exec-managerial,',
#   'Male,',
#   'Own-child,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '30,',
#   '40,',
#   '59951,',
#   'Adm-clerical,',
#   'Federal-gov,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Own-child,',
#   'Some-college,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '15,',
#   '22,',
#   '311512,',
#   'Black,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Other-service,',
#   'Some-college,',
#   'State-gov,',
#   'United-States,'},
#  {'0,',
#   '11th,',
#   '242406,',
#   '40,',
#   '48,',
#   '7,',
#   'Machine-op-inspct,',
#   'Male,',
#   'Never-married,',
#   'Private,',
#   'Puerto-Rico,',
#   'Unmarried,',
#   'White,'},
#  {'0,',
#   '10,',
#   '197200,',
#   '21,',
#   '40,',
#   'Machine-op-inspct,',
#   'Male,',
#   'Never-married,',
#   'Own-child,',
#   'Private,',
#   'Some-college,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '19,',
#   '25,',
#   '544091,',
#   '9,',
#   'Adm-clerical,',
#   'Female,',
#   'HS-grad,',
#   'Married-AF-spouse,',
#   'Private,',
#   'United-States,',
#   'White,',
#   'Wife,'},
#  {'0,',
#   '10,',
#   '31,',
#   '38,?,',
#   '84154,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'Sales,',
#   'Some-college,',
#   'White,'},
#  {'0,',
#   '12,',
#   '265477,',
#   '40,',
#   '48,',
#   'Assoc-acdm,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Prof-specialty,',
#   'Self-emp-not-inc,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '31,',
#   '43,',
#   '5,',
#   '507875,',
#   '9th,',
#   'Husband,',
#   'Machine-op-inspct,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '13,',
#   '40,',
#   '53,',
#   '88506,',
#   'Bachelors,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Prof-specialty,',
#   'Self-emp-not-inc,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '13,',
#   '172987,',
#   '24,',
#   '50,',
#   'Bachelors,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'Tech-support,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '40,',
#   '49,',
#   '9,',
#   '94638,',
#   'Adm-clerical,',
#   'Female,',
#   'HS-grad,',
#   'Private,',
#   'Separated,',
#   'United-States,',
#   'Unmarried,',
#   'White,'},
#  {'0,',
#   '25,',
#   '289980,',
#   '35,',
#   '9,',
#   'HS-grad,',
#   'Handlers-cleaners,',
#   'Male,',
#   'Never-married,',
#   'Not-in-family,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '13,',
#   '337895,',
#   '40,',
#   '57,',
#   'Bachelors,',
#   'Black,',
#   'Federal-gov,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Prof-specialty,',
#   'United-States,'},
#  {'0,',
#   '144361,',
#   '38,',
#   '53,',
#   '9,',
#   'HS-grad,',
#   'Husband,',
#   'Machine-op-inspct,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '128354,',
#   '14,',
#   '40,',
#   '44,',
#   'Divorced,',
#   'Exec-managerial,',
#   'Female,',
#   'Masters,',
#   'Private,',
#   'United-States,',
#   'Unmarried,',
#   'White,'},
#  {'0,',
#   '101603,',
#   '11,',
#   '40,',
#   '41,',
#   'Assoc-voc,',
#   'Craft-repair,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'State-gov,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '11,',
#   '271466,',
#   '29,',
#   '43,',
#   'Assoc-voc,',
#   'Male,',
#   'Never-married,',
#   'Not-in-family,',
#   'Private,',
#   'Prof-specialty,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '25,',
#   '32275,',
#   '40,',
#   'Exec-managerial,',
#   'Female,',
#   'Married-civ-spouse,',
#   'Other,',
#   'Private,',
#   'Some-college,',
#   'United-States,',
#   'Wife,'},
#  {'0,',
#   '18,',
#   '226956,',
#   '30,?,',
#   '9,',
#   'Female,',
#   'HS-grad,',
#   'Never-married,',
#   'Other-service,',
#   'Own-child,',
#   'Private,',
#   'White,'},
#  {'0,',
#   '15,',
#   '1902,',
#   '47,',
#   '51835,',
#   '60,',
#   'Female,',
#   'Honduras,',
#   'Married-civ-spouse,',
#   'Private,',
#   'Prof-school,',
#   'Prof-specialty,',
#   'White,',
#   'Wife,'},
#  {'0,',
#   '13,',
#   '251585,',
#   '50,',
#   '55,',
#   'Bachelors,',
#   'Divorced,',
#   'Exec-managerial,',
#   'Federal-gov,',
#   'Male,',
#   'Not-in-family,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '109832,',
#   '47,',
#   '60,',
#   '9,',
#   'Divorced,',
#   'Exec-managerial,',
#   'HS-grad,',
#   'Male,',
#   'Not-in-family,',
#   'Self-emp-inc,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '237993,',
#   '40,',
#   '43,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'Some-college,',
#   'Tech-support,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '216666,',
#   '3,',
#   '40,',
#   '46,',
#   '5th-6th,',
#   'Husband,',
#   'Machine-op-inspct,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Mexico,',
#   'Private,',
#   'White,'},
#  {'0,',
#   '11,',
#   '35,',
#   '40,',
#   '56352,',
#   'Assoc-voc,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Other-service,',
#   'Private,',
#   'Puerto-Rico,',
#   'White,'},
#  {'0,',
#   '147372,',
#   '41,',
#   '48,',
#   '9,',
#   'Adm-clerical,',
#   'HS-grad,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '188146,',
#   '30,',
#   '40,',
#   '5013,',
#   '9,',
#   'HS-grad,',
#   'Husband,',
#   'Machine-op-inspct,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '13,',
#   '2407,',
#   '30,',
#   '40,',
#   '59496,',
#   'Bachelors,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'Sales,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '293936,',
#   '32,?,',
#   '4,',
#   '40,?,',
#   '7th-8th,',
#   'Male,',
#   'Married-spouse-absent,?,',
#   'Not-in-family,',
#   'White,'},
#  {'0,',
#   '149640,',
#   '40,',
#   '48,',
#   '9,',
#   'HS-grad,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'Transport-moving,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '116632,',
#   '16,',
#   '42,',
#   '45,',
#   'Doctorate,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'Prof-specialty,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '105598,',
#   '29,',
#   '58,',
#   'Divorced,',
#   'Male,',
#   'Not-in-family,',
#   'Private,',
#   'Some-college,',
#   'Tech-support,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '155537,',
#   '36,',
#   '40,',
#   '9,',
#   'Craft-repair,',
#   'HS-grad,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '183175,',
#   '28,',
#   '40,',
#   'Adm-clerical,',
#   'Divorced,',
#   'Female,',
#   'Not-in-family,',
#   'Private,',
#   'Some-college,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '169846,',
#   '40,',
#   '53,',
#   '9,',
#   'Adm-clerical,',
#   'Female,',
#   'HS-grad,',
#   'Married-civ-spouse,',
#   'Private,',
#   'United-States,',
#   'White,',
#   'Wife,'},
#  {'0,',
#   '10,',
#   '191681,',
#   '49,',
#   '50,',
#   'Exec-managerial,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Self-emp-inc,',
#   'Some-college,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '200681,',
#   '25,?,',
#   '40,',
#   'Male,',
#   'Never-married,?,',
#   'Own-child,',
#   'Some-college,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '101509,',
#   '19,',
#   '32,',
#   'Male,',
#   'Never-married,',
#   'Own-child,',
#   'Private,',
#   'Prof-specialty,',
#   'Some-college,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '13,',
#   '309974,',
#   '31,',
#   '40,',
#   'Bachelors,',
#   'Black,',
#   'Female,',
#   'Own-child,',
#   'Private,',
#   'Sales,',
#   'Separated,',
#   'United-States,'},
#  {'0,',
#   '13,',
#   '162298,',
#   '29,',
#   '70,',
#   'Bachelors,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Sales,',
#   'Self-emp-not-inc,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '211678,',
#   '23,',
#   '40,',
#   'Machine-op-inspct,',
#   'Male,',
#   'Never-married,',
#   'Not-in-family,',
#   'Private,',
#   'Some-college,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '124744,',
#   '20,',
#   '79,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Other-relative,',
#   'Private,',
#   'Prof-specialty,',
#   'Some-college,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '213921,',
#   '27,',
#   '40,',
#   '9,',
#   'HS-grad,',
#   'Male,',
#   'Mexico,',
#   'Never-married,',
#   'Other-service,',
#   'Own-child,',
#   'Private,',
#   'White,'},
#  {'0,',
#   '12,',
#   '32214,',
#   '40,',
#   'Adm-clerical,',
#   'Assoc-acdm,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10th,',
#   '2,',
#   '212759,',
#   '6,',
#   '67,?,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,?,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '11th,',
#   '18,',
#   '22,',
#   '309634,',
#   '7,',
#   'Female,',
#   'Never-married,',
#   'Other-service,',
#   'Own-child,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '125927,',
#   '31,',
#   '4,',
#   '40,',
#   '7th-8th,',
#   'Farming-fishing,',
#   'Husband,',
#   'Local-gov,',
#   'Male,',
#   'Married-civ-spouse,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '18,',
#   '30,',
#   '446839,',
#   '9,',
#   'HS-grad,',
#   'Male,',
#   'Never-married,',
#   'Not-in-family,',
#   'Private,',
#   'Sales,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '13,',
#   '276515,',
#   '40,',
#   '52,',
#   'Bachelors,',
#   'Cuba,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Other-service,',
#   'Private,',
#   'White,'},
#  {'0,',
#   '40,',
#   '46,',
#   '51618,',
#   '9,',
#   'Female,',
#   'HS-grad,',
#   'Married-civ-spouse,',
#   'Other-service,',
#   'Private,',
#   'United-States,',
#   'White,',
#   'Wife,'},
#  {'0,',
#   '159937,',
#   '48,',
#   '59,',
#   '9,',
#   'HS-grad,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'Sales,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '14344,',
#   '343591,',
#   '40,',
#   '44,',
#   '9,',
#   'Craft-repair,',
#   'Divorced,',
#   'Female,',
#   'HS-grad,',
#   'Not-in-family,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '346253,',
#   '35,',
#   '53,',
#   '9,',
#   'Divorced,',
#   'Female,',
#   'HS-grad,',
#   'Own-child,',
#   'Private,',
#   'Sales,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '268234,',
#   '40,',
#   '49,',
#   '9,',
#   'HS-grad,',
#   'Husband,',
#   'Local-gov,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Protective-serv,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '14,',
#   '202051,',
#   '33,',
#   '50,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Masters,',
#   'Private,',
#   'Prof-specialty,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '30,',
#   '40,',
#   '5,',
#   '54334,',
#   '9th,',
#   'Male,',
#   'Never-married,',
#   'Not-in-family,',
#   'Private,',
#   'Sales,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '16,',
#   '410867,',
#   '43,',
#   '50,',
#   'Doctorate,',
#   'Federal-gov,',
#   'Female,',
#   'Never-married,',
#   'Not-in-family,',
#   'Prof-specialty,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '11,',
#   '249977,',
#   '40,',
#   '57,',
#   'Assoc-voc,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'Prof-specialty,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '286730,',
#   '37,',
#   '40,',
#   'Craft-repair,',
#   'Divorced,',
#   'Female,',
#   'Private,',
#   'Some-college,',
#   'United-States,',
#   'Unmarried,',
#   'White,'},
#  {'0,',
#   '10,',
#   '212563,',
#   '25,',
#   '28,',
#   'Black,',
#   'Divorced,',
#   'Female,',
#   'Machine-op-inspct,',
#   'Private,',
#   'Some-college,',
#   'United-States,',
#   'Unmarried,'},
#  {'0,',
#   '117747,',
#   '1573,',
#   '30,',
#   '35,?,',
#   '9,',
#   'Asian-Pac-Islander,',
#   'Female,',
#   'HS-grad,',
#   'Married-civ-spouse,',
#   'Private,',
#   'Sales,',
#   'Wife,'},
#  {'0,',
#   '13,',
#   '226296,',
#   '34,',
#   '40,',
#   'Bachelors,',
#   'Husband,',
#   'Local-gov,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Protective-serv,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '115585,',
#   '29,',
#   '50,',
#   'Handlers-cleaners,',
#   'Local-gov,',
#   'Male,',
#   'Never-married,',
#   'Not-in-family,',
#   'Some-college,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '16,',
#   '1902,',
#   '191277,',
#   '48,',
#   '60,',
#   'Doctorate,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Prof-specialty,',
#   'Self-emp-not-inc,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '202683,',
#   '37,',
#   '48,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'Sales,',
#   'Some-college,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '12,',
#   '171095,',
#   '40,',
#   '48,',
#   'Assoc-acdm,',
#   'Divorced,',
#   'England,',
#   'Exec-managerial,',
#   'Female,',
#   'Private,',
#   'Unmarried,',
#   'White,'},
#  {'0,',
#   '249409,',
#   '32,',
#   '40,',
#   '9,',
#   'Black,',
#   'Federal-gov,',
#   'HS-grad,',
#   'Male,',
#   'Never-married,',
#   'Other-service,',
#   'Own-child,',
#   'United-States,'},
#  {'0,',
#   '124191,',
#   '14,',
#   '40,',
#   '76,',
#   'Exec-managerial,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Masters,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '13,',
#   '15024,',
#   '198282,',
#   '44,',
#   '60,',
#   'Bachelors,',
#   'Exec-managerial,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '14,',
#   '149116,',
#   '47,',
#   '50,',
#   'Female,',
#   'Masters,',
#   'Never-married,',
#   'Not-in-family,',
#   'Prof-specialty,',
#   'Self-emp-not-inc,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '188300,',
#   '20,',
#   '40,',
#   'Female,',
#   'Never-married,',
#   'Own-child,',
#   'Private,',
#   'Some-college,',
#   'Tech-support,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '103432,',
#   '29,',
#   '40,',
#   '9,',
#   'Craft-repair,',
#   'HS-grad,',
#   'Male,',
#   'Never-married,',
#   'Not-in-family,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '317660,',
#   '32,',
#   '40,',
#   '7688,',
#   '9,',
#   'Craft-repair,',
#   'HS-grad,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Self-emp-inc,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10th,',
#   '17,?,',
#   '304873,',
#   '32,',
#   '34095,',
#   '6,',
#   'Female,',
#   'Never-married,?,',
#   'Own-child,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '11th,',
#   '194901,',
#   '30,',
#   '40,',
#   '7,',
#   'Handlers-cleaners,',
#   'Male,',
#   'Never-married,',
#   'Own-child,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '189265,',
#   '31,',
#   '40,',
#   '9,',
#   'Adm-clerical,',
#   'Female,',
#   'HS-grad,',
#   'Local-gov,',
#   'Never-married,',
#   'Not-in-family,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '124692,',
#   '40,',
#   '42,',
#   '9,',
#   'HS-grad,',
#   'Handlers-cleaners,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '13,',
#   '24,',
#   '40,',
#   '432376,',
#   'Bachelors,',
#   'Male,',
#   'Never-married,',
#   'Other-relative,',
#   'Private,',
#   'Sales,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '15,',
#   '38,',
#   '40,',
#   '65324,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'Prof-school,',
#   'Prof-specialty,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '1887,',
#   '335605,',
#   '50,',
#   '56,',
#   '9,',
#   'Canada,',
#   'HS-grad,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Other-service,',
#   'Self-emp-not-inc,',
#   'White,'},
#  {'0,',
#   '10,',
#   '25,',
#   '28,',
#   '377869,',
#   '4064,',
#   'Female,',
#   'Married-civ-spouse,',
#   'Private,',
#   'Sales,',
#   'Some-college,',
#   'United-States,',
#   'White,',
#   'Wife,'},
#  {'0,',
#   '102864,',
#   '36,',
#   '40,',
#   '9,',
#   'Female,',
#   'HS-grad,',
#   'Machine-op-inspct,',
#   'Never-married,',
#   'Own-child,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '5,',
#   '50,',
#   '53,',
#   '95647,',
#   '9th,',
#   'Handlers-cleaners,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '303090,',
#   '50,',
#   '56,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Sales,',
#   'Self-emp-inc,',
#   'Some-college,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '11,',
#   '197371,',
#   '40,',
#   '49,',
#   'Assoc-voc,',
#   'Black,',
#   'Craft-repair,',
#   'Husband,',
#   'Local-gov,',
#   'Male,',
#   'Married-civ-spouse,',
#   'United-States,'},
#  {'0,',
#   '10,',
#   '247552,',
#   '55,',
#   '56,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'Sales,',
#   'Some-college,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '102632,',
#   '22,',
#   '41,',
#   '9,',
#   'Craft-repair,',
#   'HS-grad,',
#   'Male,',
#   'Never-married,',
#   'Not-in-family,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '199915,',
#   '21,',
#   '40,',
#   'Female,',
#   'Never-married,',
#   'Other-service,',
#   'Own-child,',
#   'Private,',
#   'Some-college,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '118853,',
#   '13,',
#   '40,',
#   '60,',
#   'Bachelors,',
#   'Exec-managerial,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '13,',
#   '30,',
#   '40,',
#   '77143,',
#   'Bachelors,',
#   'Black,',
#   'Exec-managerial,',
#   'Germany,',
#   'Male,',
#   'Never-married,',
#   'Own-child,',
#   'Private,'},
#  {'0,',
#   '13,',
#   '267989,',
#   '29,',
#   '50,',
#   'Bachelors,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Prof-specialty,',
#   'State-gov,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '19,',
#   '301606,',
#   '35,',
#   'Black,',
#   'Male,',
#   'Never-married,',
#   'Other-service,',
#   'Own-child,',
#   'Private,',
#   'Some-college,',
#   'United-States,'},
#  {'0,',
#   '13,',
#   '287828,',
#   '40,',
#   '47,',
#   'Bachelors,',
#   'Exec-managerial,',
#   'Female,',
#   'Married-civ-spouse,',
#   'Private,',
#   'United-States,',
#   'White,',
#   'Wife,'},
#  {'0,',
#   '10,',
#   '111697,',
#   '1719,',
#   '20,',
#   '28,',
#   'Adm-clerical,',
#   'Female,',
#   'Never-married,',
#   'Own-child,',
#   'Private,',
#   'Some-college,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '114937,',
#   '12,',
#   '31,',
#   '40,',
#   'Adm-clerical,',
#   'Assoc-acdm,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '129305,',
#   '35,?,',
#   '40,',
#   '9,',
#   'HS-grad,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,?,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '365739,',
#   '39,',
#   '40,',
#   'Craft-repair,',
#   'Divorced,',
#   'Male,',
#   'Not-in-family,',
#   'Private,',
#   'Some-college,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '12,',
#   '28,',
#   '60,',
#   '69621,',
#   'Assoc-acdm,',
#   'Female,',
#   'Never-married,',
#   'Not-in-family,',
#   'Private,',
#   'Sales,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '1762,',
#   '24,',
#   '40,',
#   '43323,',
#   '9,',
#   'Female,',
#   'HS-grad,',
#   'Never-married,',
#   'Not-in-family,',
#   'Other-service,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '120985,',
#   '35,',
#   '38,',
#   '4386,',
#   '9,',
#   'Craft-repair,',
#   'HS-grad,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Self-emp-not-inc,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '13,',
#   '254202,',
#   '37,',
#   '50,',
#   'Bachelors,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'Sales,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '12,',
#   '146195,',
#   '36,',
#   '46,',
#   'Assoc-acdm,',
#   'Black,',
#   'Divorced,',
#   'Female,',
#   'Not-in-family,',
#   'Private,',
#   'Tech-support,',
#   'United-States,'},
#  {'0,',
#   '125933,',
#   '14,',
#   '38,',
#   '40,',
#   'Federal-gov,',
#   'Husband,',
#   'Iran,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Masters,',
#   'Prof-specialty,',
#   'White,'},
#  {'0,',
#   '43,',
#   '56920,',
#   '60,',
#   '9,',
#   'Craft-repair,',
#   'HS-grad,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Self-emp-not-inc,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '11,',
#   '163127,',
#   '27,',
#   '35,',
#   'Adm-clerical,',
#   'Assoc-voc,',
#   'Female,',
#   'Married-civ-spouse,',
#   'Private,',
#   'United-States,',
#   'White,',
#   'Wife,'},
#  {'0,',
#   '10,',
#   '20,',
#   '34310,',
#   'Male,',
#   'Never-married,',
#   'Own-child,',
#   'Private,',
#   'Sales,',
#   'Some-college,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '40,',
#   '49,',
#   '81973,',
#   'Asian-Pac-Islander,',
#   'Craft-repair,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'Some-college,',
#   'United-States,'},
#  {'0,',
#   '40,',
#   '61,',
#   '66614,',
#   '9,',
#   'Craft-repair,',
#   'HS-grad,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Self-emp-inc,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '232782,',
#   '27,',
#   '40,',
#   'Female,',
#   'Never-married,',
#   'Own-child,',
#   'Private,',
#   'Sales,',
#   'Some-college,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '19,',
#   '30,',
#   '316868,',
#   'Male,',
#   'Mexico,',
#   'Never-married,',
#   'Other-service,',
#   'Own-child,',
#   'Private,',
#   'Some-college,',
#   'White,'},
#  {'0,',
#   '11,',
#   '1564,',
#   '196584,',
#   '40,',
#   '45,',
#   'Assoc-voc,',
#   'Female,',
#   'Never-married,',
#   'Not-in-family,',
#   'Private,',
#   'Prof-specialty,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '105376,',
#   '40,',
#   '70,',
#   'Male,',
#   'Never-married,',
#   'Other-relative,',
#   'Private,',
#   'Some-college,',
#   'Tech-support,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '185814,',
#   '30,',
#   '31,',
#   '9,',
#   'Black,',
#   'Female,',
#   'HS-grad,',
#   'Never-married,',
#   'Private,',
#   'Transport-moving,',
#   'United-States,',
#   'Unmarried,'},
#  {'0,',
#   '10,',
#   '175374,',
#   '22,',
#   '24,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Other-service,',
#   'Private,',
#   'Some-college,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '108293,',
#   '24,',
#   '36,',
#   '9,',
#   'Female,',
#   'HS-grad,',
#   'Other-service,',
#   'Private,',
#   'United-States,',
#   'Unmarried,',
#   'White,',
#   'Widowed,'},
#  {'0,',
#   '11th,',
#   '181232,',
#   '2179,',
#   '40,',
#   '64,',
#   '7,',
#   'Craft-repair,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '174662,',
#   '40,',
#   '43,?,',
#   'Divorced,?,',
#   'Female,',
#   'Not-in-family,',
#   'Some-college,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '186009,',
#   '38,',
#   '47,',
#   'Adm-clerical,',
#   'Divorced,',
#   'Female,',
#   'Local-gov,',
#   'Mexico,',
#   'Some-college,',
#   'Unmarried,',
#   'White,'},
#  {'0,',
#   '198183,',
#   '34,',
#   '40,',
#   '9,',
#   'Adm-clerical,',
#   'Female,',
#   'HS-grad,',
#   'Never-married,',
#   'Not-in-family,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '13,',
#   '163003,',
#   '33,',
#   '40,',
#   'Asian-Pac-Islander,',
#   'Bachelors,',
#   'Exec-managerial,',
#   'Female,',
#   'Never-married,',
#   'Other-relative,',
#   'Philippines,',
#   'Private,'},
#  {'0,',
#   '21,',
#   '296158,',
#   '35,',
#   '9,',
#   'Craft-repair,',
#   'HS-grad,',
#   'Male,',
#   'Never-married,',
#   'Own-child,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '252903,',
#   '45,',
#   '52,?,',
#   '9,',
#   'Divorced,?,',
#   'HS-grad,',
#   'Male,',
#   'Not-in-family,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '187715,',
#   '46,',
#   '48,',
#   '9,',
#   'Craft-repair,',
#   'HS-grad,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '13,',
#   '214542,',
#   '23,',
#   '40,',
#   'Bachelors,',
#   'Handlers-cleaners,',
#   'Male,',
#   'Never-married,',
#   'Not-in-family,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '1816,',
#   '2,',
#   '494223,',
#   '71,',
#   'Black,',
#   'Male,',
#   'Sales,',
#   'Self-emp-not-inc,',
#   'Separated,',
#   'Some-college,',
#   'United-States,',
#   'Unmarried,'},
#  {'0,',
#   '191535,',
#   '29,',
#   '60,',
#   '9,',
#   'Craft-repair,',
#   'Divorced,',
#   'HS-grad,',
#   'Male,',
#   'Not-in-family,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '13,',
#   '228456,',
#   '42,',
#   '50,',
#   'Bachelors,',
#   'Black,',
#   'Male,',
#   'Other-relative,',
#   'Other-service,',
#   'Private,',
#   'Separated,',
#   'United-States,'},
#  {'0,',
#   '1st-4th,',
#   '2,',
#   '20,',
#   '38317,',
#   '68,?,',
#   'Divorced,?,',
#   'Female,',
#   'Not-in-family,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '25,',
#   '252752,',
#   '40,',
#   '9,',
#   'Female,',
#   'HS-grad,',
#   'Never-married,',
#   'Other-service,',
#   'Private,',
#   'United-States,',
#   'Unmarried,',
#   'White,'},
#  {'0,',
#   '14,',
#   '40,',
#   '44,',
#   '78374,',
#   'Asian-Pac-Islander,',
#   'Divorced,',
#   'Exec-managerial,',
#   'Female,',
#   'Masters,',
#   'Self-emp-inc,',
#   'United-States,',
#   'Unmarried,'},
#  {'0,',
#   '28,',
#   '40,',
#   '88419,',
#   '9,',
#   'Asian-Pac-Islander,',
#   'England,',
#   'Exec-managerial,',
#   'Female,',
#   'HS-grad,',
#   'Never-married,',
#   'Not-in-family,',
#   'Private,'},
#  {'0,',
#   '14,',
#   '201080,',
#   '40,',
#   '45,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Masters,',
#   'Sales,',
#   'Self-emp-not-inc,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '207157,',
#   '36,',
#   '40,',
#   'Divorced,',
#   'Female,',
#   'Mexico,',
#   'Other-service,',
#   'Private,',
#   'Some-college,',
#   'Unmarried,',
#   'White,'},
#  {'0,',
#   '12,',
#   '235485,',
#   '39,',
#   '42,',
#   'Assoc-acdm,',
#   'Exec-managerial,',
#   'Federal-gov,',
#   'Male,',
#   'Never-married,',
#   'Not-in-family,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '102628,',
#   '14,',
#   '40,',
#   '46,',
#   'Male,',
#   'Masters,',
#   'Protective-serv,',
#   'State-gov,',
#   'United-States,',
#   'Unmarried,',
#   'White,',
#   'Widowed,'},
#  {'0,',
#   '11th,',
#   '16,',
#   '18,',
#   '25828,',
#   '7,',
#   'Handlers-cleaners,',
#   'Male,',
#   'Never-married,',
#   'Own-child,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '11,',
#   '20,',
#   '54826,',
#   '66,',
#   'Assoc-voc,',
#   'Female,',
#   'Local-gov,',
#   'Not-in-family,',
#   'Prof-specialty,',
#   'United-States,',
#   'White,',
#   'Widowed,'},
#  {'0,',
#   '124953,',
#   '1980,',
#   '27,',
#   '40,',
#   '9,',
#   'HS-grad,',
#   'Male,',
#   'Never-married,',
#   'Not-in-family,',
#   'Other-service,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '175325,',
#   '28,',
#   '40,',
#   '9,',
#   'HS-grad,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Protective-serv,',
#   'State-gov,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '1977,',
#   '40,',
#   '51,',
#   '96062,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'Sales,',
#   'Some-college,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '13,',
#   '27,',
#   '428030,',
#   '50,',
#   'Bachelors,',
#   'Craft-repair,',
#   'Male,',
#   'Never-married,',
#   'Not-in-family,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '13,',
#   '149624,',
#   '28,',
#   '40,',
#   'Bachelors,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Prof-specialty,',
#   'State-gov,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '25,',
#   '253814,',
#   '27,',
#   '9,',
#   'Female,',
#   'HS-grad,',
#   'Married-spouse-absent,',
#   'Private,',
#   'Sales,',
#   'United-States,',
#   'Unmarried,',
#   'White,'},
#  {'0,',
#   '21,',
#   '312956,',
#   '40,',
#   '9,',
#   'Black,',
#   'Craft-repair,',
#   'HS-grad,',
#   'Male,',
#   'Never-married,',
#   'Own-child,',
#   'Private,',
#   'United-States,'},
#  {'0,',
#   '34,',
#   '40,',
#   '483777,',
#   '9,',
#   'Black,',
#   'HS-grad,',
#   'Handlers-cleaners,',
#   'Male,',
#   'Never-married,',
#   'Not-in-family,',
#   'Private,',
#   'United-States,'},
#  {'0,',
#   '12,',
#   '18,',
#   '183930,',
#   '9,',
#   'HS-grad,',
#   'Male,',
#   'Never-married,',
#   'Other-service,',
#   'Own-child,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '13,',
#   '33,',
#   '37274,',
#   '65,',
#   'Bachelors,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'Prof-specialty,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '181344,',
#   '38,',
#   '44,',
#   'Black,',
#   'Exec-managerial,',
#   'Husband,',
#   'Local-gov,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Some-college,',
#   'United-States,'},
#  {'0,',
#   '10,',
#   '114580,',
#   '40,',
#   '43,',
#   'Adm-clerical,',
#   'Divorced,',
#   'Female,',
#   'Not-in-family,',
#   'Private,',
#   'Some-college,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '30,',
#   '45,',
#   '633742,',
#   'Black,',
#   'Craft-repair,',
#   'Male,',
#   'Never-married,',
#   'Not-in-family,',
#   'Private,',
#   'Some-college,',
#   'United-States,'},
#  {'0,',
#   '286370,',
#   '4,',
#   '40,',
#   '7th-8th,',
#   'Husband,',
#   'Machine-op-inspct,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Mexico,',
#   'Private,',
#   'White,'},
#  {'0,',
#   '10,',
#   '29054,',
#   '37,',
#   '42,',
#   'Adm-clerical,',
#   'Federal-gov,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Some-college,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '304030,',
#   '34,',
#   '40,',
#   '9,',
#   'Adm-clerical,',
#   'Black,',
#   'HS-grad,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'United-States,'},
#  {'0,',
#   '13,',
#   '143129,',
#   '40,',
#   '41,',
#   'Bachelors,',
#   'Divorced,',
#   'Exec-managerial,',
#   'Female,',
#   'Not-in-family,',
#   'Self-emp-not-inc,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '13,',
#   '135105,',
#   '50,',
#   '53,?,',
#   'Bachelors,',
#   'Divorced,?,',
#   'Female,',
#   'Not-in-family,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '14,',
#   '31,',
#   '50,',
#   '99928,',
#   'Female,',
#   'Married-civ-spouse,',
#   'Masters,',
#   'Private,',
#   'Prof-specialty,',
#   'United-States,',
#   'White,',
#   'Wife,'},
#  {'0,',
#   '1,',
#   '109567,',
#   '16,',
#   '58,',
#   'Doctorate,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Prof-specialty,',
#   'State-gov,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '155222,',
#   '28,',
#   '38,',
#   'Black,',
#   'Divorced,',
#   'Female,',
#   'Machine-op-inspct,',
#   'Not-in-family,',
#   'Private,',
#   'Some-college,',
#   'United-States,'},
#  {'0,',
#   '10,',
#   '159567,',
#   '24,',
#   '40,',
#   'Husband,',
#   'Machine-op-inspct,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'Some-college,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '13,',
#   '40,',
#   '41,',
#   '523910,',
#   'Bachelors,',
#   'Black,',
#   'Craft-repair,',
#   'Husband,',
#   'Local-gov,',
#   'Male,',
#   'Married-civ-spouse,',
#   'United-States,'},
#  {'0,',
#   '10,',
#   '120939,',
#   '45,',
#   '47,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'Some-college,',
#   'Tech-support,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '13,',
#   '130760,',
#   '24,',
#   '41,',
#   'Bachelors,',
#   'Federal-gov,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Tech-support,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '197387,',
#   '23,',
#   '3,',
#   '40,',
#   '5th-6th,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Mexico,',
#   'Other-relative,',
#   'Private,',
#   'Transport-moving,',
#   'White,'},
#  {'0,',
#   '10,',
#   '36,',
#   '40,',
#   '99374,',
#   'Craft-repair,',
#   'Divorced,',
#   'Male,',
#   'Not-in-family,',
#   'Private,',
#   'Some-college,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '14,',
#   '14084,',
#   '40,',
#   '55,',
#   '56795,',
#   'Exec-managerial,',
#   'Federal-gov,',
#   'Female,',
#   'Masters,',
#   'Never-married,',
#   'Not-in-family,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '138992,',
#   '14,',
#   '35,',
#   '40,',
#   '7298,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Masters,',
#   'Other-relative,',
#   'Private,',
#   'Prof-specialty,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '24,',
#   '32921,',
#   '40,',
#   '9,',
#   'HS-grad,',
#   'Male,',
#   'Never-married,',
#   'Not-in-family,',
#   'Sales,',
#   'Self-emp-not-inc,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '14,',
#   '1876,',
#   '26,',
#   '397317,',
#   '40,',
#   'Female,',
#   'Masters,',
#   'Never-married,',
#   'Not-in-family,',
#   'Private,',
#   'Prof-specialty,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '170653,',
#   '19,?,',
#   '40,',
#   '9,',
#   'HS-grad,',
#   'Italy,',
#   'Male,',
#   'Never-married,?,',
#   'Own-child,',
#   'White,'},
#  {'0,',
#   '13,',
#   '259323,',
#   '50,',
#   '51,',
#   'Bachelors,',
#   'Exec-managerial,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '1340,',
#   '254817,',
#   '40,',
#   '42,',
#   'Female,',
#   'Local-gov,',
#   'Never-married,',
#   'Not-in-family,',
#   'Prof-specialty,',
#   'Some-college,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '35,',
#   '37,',
#   '48211,',
#   '9,',
#   'Adm-clerical,',
#   'Divorced,',
#   'Female,',
#   'HS-grad,',
#   'State-gov,',
#   'United-States,',
#   'Unmarried,',
#   'White,'},
#  {'0,',
#   '11th,',
#   '140164,',
#   '18,',
#   '40,',
#   '7,',
#   'Female,',
#   'Never-married,',
#   'Own-child,',
#   'Private,',
#   'Sales,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '128757,',
#   '13,',
#   '36,',
#   '7298,',
#   'Bachelors,',
#   'Black,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Other-service,',
#   'Private,',
#   'United-States,'},
#  {'0,',
#   '35,',
#   '36270,',
#   '60,',
#   '9,',
#   'Craft-repair,',
#   'Divorced,',
#   'HS-grad,',
#   'Male,',
#   'Not-in-family,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '15024,',
#   '210563,',
#   '35,',
#   '58,',
#   '9,',
#   'Female,',
#   'HS-grad,',
#   'Married-civ-spouse,',
#   'Sales,',
#   'Self-emp-inc,',
#   'United-States,',
#   'White,',
#   'Wife,'},
#  {'0,',
#   '11th,',
#   '12,',
#   '17,',
#   '65368,',
#   '7,',
#   'Female,',
#   'Never-married,',
#   'Own-child,',
#   'Private,',
#   'Sales,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '160943,',
#   '40,',
#   '44,',
#   '9,',
#   'Black,',
#   'HS-grad,',
#   'Husband,',
#   'Local-gov,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Transport-moving,',
#   'United-States,'},
#  {'0,',
#   '208358,',
#   '37,',
#   '40,',
#   '9,',
#   'Craft-repair,',
#   'HS-grad,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '153790,',
#   '35,',
#   '40,',
#   'Amer-Indian-Eskimo,',
#   'Female,',
#   'Never-married,',
#   'Not-in-family,',
#   'Private,',
#   'Sales,',
#   'Some-college,',
#   'United-States,'},
#  {'0,',
#   '40,',
#   '60,',
#   '85815,',
#   '9,',
#   'Asian-Pac-Islander,',
#   'Craft-repair,',
#   'HS-grad,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'United-States,'},
#  {'0,',
#   '125417,',
#   '4,',
#   '40,',
#   '54,',
#   '7th-8th,',
#   'Husband,',
#   'Machine-op-inspct,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Self-emp-inc,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '13,',
#   '37,',
#   '60,',
#   '635913,',
#   'Bachelors,',
#   'Black,',
#   'Exec-managerial,',
#   'Male,',
#   'Never-married,',
#   'Not-in-family,',
#   'Private,',
#   'United-States,'},
#  {'0,',
#   '12,',
#   '313321,',
#   '40,',
#   '50,',
#   'Assoc-acdm,',
#   'Divorced,',
#   'Female,',
#   'Not-in-family,',
#   'Private,',
#   'Sales,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '13,',
#   '182609,',
#   '38,',
#   '50,',
#   'Bachelors,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Poland,',
#   'Private,',
#   'Sales,',
#   'White,'},
#  {'0,',
#   '109434,',
#   '13,',
#   '45,',
#   '55,',
#   'Bachelors,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'Prof-specialty,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10th,',
#   '25,',
#   '255004,',
#   '40,',
#   '6,',
#   'Craft-repair,',
#   'Male,',
#   'Never-married,',
#   'Not-in-family,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '197860,',
#   '31,',
#   '40,',
#   'Handlers-cleaners,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'Some-college,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '187656,',
#   '1st-4th,',
#   '2,',
#   '40,',
#   '64,?,',
#   'Divorced,?,',
#   'Male,',
#   'Not-in-family,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '2206,',
#   '40,',
#   '51744,',
#   '9,',
#   '90,',
#   'Black,',
#   'HS-grad,',
#   'Male,',
#   'Never-married,',
#   'Not-in-family,',
#   'Other-service,',
#   'Private,',
#   'United-States,'},
#  {'0,',
#   '176681,',
#   '20,',
#   '54,',
#   '9,',
#   'Adm-clerical,',
#   'Black,',
#   'HS-grad,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'United-States,'},
#  {'0,',
#   '1,',
#   '140359,',
#   '35,',
#   '53,',
#   'Female,',
#   'Local-gov,',
#   'Machine-op-inspct,',
#   'Never-married,',
#   'Not-in-family,',
#   'Preschool,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '18,',
#   '243313,',
#   '40,',
#   '9,',
#   'Female,',
#   'HS-grad,',
#   'Never-married,',
#   'Own-child,',
#   'Private,',
#   'Sales,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '10th,',
#   '24215,',
#   '6,',
#   '60,?,',
#   'Amer-Indian-Eskimo,',
#   'Divorced,?,',
#   'Female,',
#   'Not-in-family,',
#   'United-States,'},
#  {'0,',
#   '1409,',
#   '167687,',
#   '50,',
#   '66,',
#   '9,',
#   'Farming-fishing,',
#   'HS-grad,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Self-emp-not-inc,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '11,',
#   '20,',
#   '314209,',
#   '75,',
#   'Adm-clerical,',
#   'Assoc-voc,',
#   'Columbia,',
#   'Female,',
#   'Not-in-family,',
#   'Private,',
#   'White,',
#   'Widowed,'},
#  {'0,',
#   '176796,',
#   '40,',
#   '65,',
#   '9,',
#   'Adm-clerical,',
#   'Divorced,',
#   'Female,',
#   'HS-grad,',
#   'Not-in-family,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '11th,',
#   '35,',
#   '3674,',
#   '40,',
#   '538583,',
#   '7,',
#   'Black,',
#   'Male,',
#   'Not-in-family,',
#   'Private,',
#   'Separated,',
#   'Transport-moving,',
#   'United-States,'},
#  {'0,',
#   '130408,',
#   '38,',
#   '41,',
#   '9,',
#   'Black,',
#   'Divorced,',
#   'Female,',
#   'HS-grad,',
#   'Private,',
#   'Sales,',
#   'United-States,',
#   'Unmarried,'},
#  {'0,',
#   '10,',
#   '159732,',
#   '25,',
#   '42,',
#   'Adm-clerical,',
#   'Male,',
#   'Never-married,',
#   'Not-in-family,',
#   'Private,',
#   'Some-college,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '110978,',
#   '33,',
#   '40,',
#   'Craft-repair,',
#   'Divorced,',
#   'Female,',
#   'Other,',
#   'Other-relative,',
#   'Private,',
#   'Some-college,',
#   'United-States,'},
#  {'0,',
#   '15,',
#   '28,',
#   '55,',
#   '76714,',
#   'Male,',
#   'Never-married,',
#   'Not-in-family,',
#   'Private,',
#   'Prof-school,',
#   'Prof-specialty,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '268700,',
#   '40,',
#   '59,',
#   '9,',
#   'HS-grad,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Other-service,',
#   'State-gov,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '170525,',
#   '38,',
#   '40,',
#   'Adm-clerical,',
#   'Female,',
#   'Never-married,',
#   'Not-in-family,',
#   'Some-college,',
#   'State-gov,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '13,',
#   '180138,',
#   '41,',
#   '50,',
#   'Bachelors,',
#   'Exec-managerial,',
#   'Husband,',
#   'Iran,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'White,'},
#  {'0,',
#   '115076,',
#   '14,',
#   '38,',
#   '70,',
#   'Exec-managerial,',
#   'Husband,',
#   'Local-gov,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Masters,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '115458,',
#   '23,',
#   '40,',
#   '9,',
#   'HS-grad,',
#   'Male,',
#   'Never-married,',
#   'Own-child,',
#   'Private,',
#   'Transport-moving,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '13,',
#   '347890,',
#   '40,',
#   'Bachelors,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'Prof-specialty,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '196001,',
#   '20,',
#   '41,',
#   '9,',
#   'Female,',
#   'HS-grad,',
#   'Married-civ-spouse,',
#   'Other-service,',
#   'Self-emp-not-inc,',
#   'United-States,',
#   'White,',
#   'Wife,'},
#  {'0,',
#   '12,',
#   '24,',
#   '273905,',
#   '50,',
#   'Assoc-acdm,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Protective-serv,',
#   'State-gov,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '119156,',
#   '20,',
#   '20,?,',
#   'Male,',
#   'Never-married,?,',
#   'Own-child,',
#   'Some-college,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '1741,',
#   '179488,',
#   '38,',
#   '40,',
#   'Craft-repair,',
#   'Divorced,',
#   'Male,',
#   'Not-in-family,',
#   'Private,',
#   'Some-college,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '203580,',
#   '35,?,',
#   '56,',
#   '9,',
#   'Adm-clerical,',
#   'HS-grad,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'White,'},
#  {'0,',
#   '236596,',
#   '45,',
#   '58,',
#   '9,',
#   'Adm-clerical,',
#   'HS-grad,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '183916,',
#   '32,',
#   '34,',
#   '9,',
#   'Female,',
#   'HS-grad,',
#   'Never-married,',
#   'Not-in-family,',
#   'Other-service,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '12,',
#   '1977,',
#   '207578,',
#   '40,',
#   '60,',
#   'Assoc-acdm,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'Tech-support,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '153141,',
#   '40,?,',
#   '45,',
#   '9,',
#   'Adm-clerical,',
#   'HS-grad,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'White,'},
#  {'0,',
#   '112763,',
#   '15,',
#   '40,',
#   '41,',
#   'Female,',
#   'Married-civ-spouse,',
#   'Private,',
#   'Prof-school,',
#   'Prof-specialty,',
#   'United-States,',
#   'White,',
#   'Wife,'},
#  {'0,',
#   '13,',
#   '390781,',
#   '40,',
#   '42,',
#   'Adm-clerical,',
#   'Bachelors,',
#   'Black,',
#   'Female,',
#   'Married-civ-spouse,',
#   'Private,',
#   'United-States,',
#   'Wife,'},
#  {'0,',
#   '10th,',
#   '171328,',
#   '30,',
#   '59,',
#   '6,',
#   'Black,',
#   'Female,',
#   'Local-gov,',
#   'Other-service,',
#   'United-States,',
#   'Unmarried,',
#   'Widowed,'},
#  {'0,',
#   '10,',
#   '19,',
#   '27382,',
#   '40,',
#   'Adm-clerical,',
#   'Local-gov,',
#   'Male,',
#   'Never-married,',
#   'Own-child,',
#   'Some-college,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '20,',
#   '259014,',
#   '58,',
#   'Male,',
#   'Never-married,',
#   'Not-in-family,',
#   'Private,',
#   'Some-college,',
#   'Transport-moving,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '303044,',
#   '40,',
#   '42,',
#   '9,',
#   'Asian-Pac-Islander,',
#   'Cambodia,',
#   'Farming-fishing,',
#   'HS-grad,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Self-emp-not-inc,'},
#  {'0,',
#   '117789,',
#   '20,',
#   '40,',
#   '9,',
#   'Female,',
#   'HS-grad,',
#   'Never-married,',
#   'Other-service,',
#   'Own-child,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '172579,',
#   '30,',
#   '32,',
#   '9,',
#   'Female,',
#   'HS-grad,',
#   'Not-in-family,',
#   'Other-service,',
#   'Private,',
#   'Separated,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '11,',
#   '187666,',
#   '45,',
#   'Assoc-voc,',
#   'Exec-managerial,',
#   'Female,',
#   'Not-in-family,',
#   'Private,',
#   'United-States,',
#   'White,',
#   'Widowed,'},
#  {'0,',
#   '204518,',
#   '4,',
#   '40,',
#   '50,',
#   '7th-8th,',
#   'Craft-repair,',
#   'Divorced,',
#   'Male,',
#   'Not-in-family,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '13,',
#   '150042,',
#   '36,',
#   '40,',
#   'Bachelors,',
#   'Divorced,',
#   'Female,',
#   'Own-child,',
#   'Private,',
#   'Prof-specialty,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '45,',
#   '60,',
#   '9,',
#   '98092,',
#   'HS-grad,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'Sales,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '11th,',
#   '12,',
#   '17,',
#   '245918,',
#   '7,',
#   'Male,',
#   'Never-married,',
#   'Other-service,',
#   'Own-child,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '146013,',
#   '40,',
#   '4064,',
#   '59,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'Sales,',
#   'Some-college,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '11th,',
#   '26,',
#   '378322,',
#   '40,',
#   '7,',
#   'Craft-repair,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '257295,',
#   '37,',
#   '75,',
#   'Asian-Pac-Islander,',
#   'Exec-managerial,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Self-emp-inc,',
#   'Some-college,',
#   'Thailand,'},
#  {'0,',
#   '10,',
#   '19,?,',
#   '218956,',
#   '24,',
#   'Canada,',
#   'Male,',
#   'Never-married,?,',
#   'Own-child,',
# ...
#   'United-States,',
#   'White,'},
#  {'0,',
#   '27,',
#   '30,',
#   '9,',
#   '93235,',
#   'HS-grad,',
#   'Male,',
#   'Never-married,',
#   'Not-in-family,',
#   'Private,',
#   'Sales,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '278924,',
#   '38,',
#   '44,',
#   'Craft-repair,',
#   'Divorced,',
#   'Male,',
#   'Not-in-family,',
#   'Private,',
#   'Some-college,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10th,',
#   '311020,',
#   '53,',
#   '6,',
#   '60,',
#   'Farming-fishing,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Self-emp-not-inc,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '175878,',
#   '34,',
#   '40,',
#   'Craft-repair,',
#   'Male,',
#   'Never-married,',
#   'Not-in-family,',
#   'Private,',
#   'Some-college,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '23,',
#   '40,',
#   '543028,',
#   '9,',
#   'Black,',
#   'HS-grad,',
#   'Male,',
#   'Never-married,',
#   'Own-child,',
#   'Private,',
#   'Sales,',
#   'United-States,'},
#  {'0,',
#   '13,',
#   '15024,',
#   '202027,',
#   '39,',
#   '45,',
#   'Bachelors,',
#   'Exec-managerial,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '14,',
#   '158926,',
#   '43,',
#   '50,',
#   'Asian-Pac-Islander,',
#   'Female,',
#   'Married-civ-spouse,',
#   'Masters,',
#   'Private,',
#   'Prof-specialty,',
#   'South,',
#   'Wife,'},
#  {'0,',
#   '40,',
#   '67,',
#   '76860,',
#   '9,',
#   'Asian-Pac-Islander,',
#   'Exec-managerial,',
#   'HS-grad,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Self-emp-inc,',
#   'United-States,'},
#  {'0,',
#   '136063,',
#   '30,',
#   '81,',
#   '9,',
#   'Exec-managerial,',
#   'HS-grad,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Self-emp-not-inc,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '186648,',
#   '20,',
#   '21,',
#   'Male,',
#   'Never-married,',
#   'Other-service,',
#   'Own-child,',
#   'Private,',
#   'Some-college,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '23,',
#   '25,',
#   '257509,',
#   'Male,',
#   'Never-married,',
#   'Not-in-family,',
#   'Private,',
#   'Sales,',
#   'Some-college,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '25,',
#   '40,',
#   '98155,',
#   'Male,',
#   'Never-married,',
#   'Private,',
#   'Some-college,',
#   'Transport-moving,',
#   'United-States,',
#   'Unmarried,',
#   'White,'},
#  {'0,',
#   '274198,',
#   '3,',
#   '38,',
#   '42,',
#   '5th-6th,',
#   'Female,',
#   'Machine-op-inspct,',
#   'Married-civ-spouse,',
#   'Mexico,',
#   'Private,',
#   'White,',
#   'Wife,'},
#  {'0,',
#   '10,',
#   '38,',
#   '40,',
#   '97083,',
#   'Adm-clerical,',
#   'Black,',
#   'Female,',
#   'Married-civ-spouse,',
#   'Private,',
#   'Some-college,',
#   'United-States,',
#   'Wife,'},
#  {'0,',
#   '29825,',
#   '5,',
#   '64,?,',
#   '9,',
#   'HS-grad,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,?,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '262153,',
#   '32,',
#   '40,',
#   '9,',
#   'HS-grad,',
#   'Husband,',
#   'Machine-op-inspct,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '214738,',
#   '37,',
#   '40,',
#   '9,',
#   'HS-grad,',
#   'Husband,',
#   'Machine-op-inspct,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '138022,',
#   '14,',
#   '51,',
#   '60,',
#   'Exec-managerial,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Masters,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '22,',
#   '42,',
#   '91842,',
#   'Female,',
#   'Never-married,',
#   'Not-in-family,',
#   'Private,',
#   'Sales,',
#   'Some-college,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '1st-4th,',
#   '2,',
#   '33,',
#   '373662,',
#   '40,',
#   'Female,',
#   'Guatemala,',
#   'Married-spouse-absent,',
#   'Not-in-family,',
#   'Priv-house-serv,',
#   'Private,',
#   'White,'},
#  {'0,',
#   '162003,',
#   '42,',
#   '55,',
#   '9,',
#   'Divorced,',
#   'HS-grad,',
#   'Machine-op-inspct,',
#   'Male,',
#   'Not-in-family,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '19,?,',
#   '52114,',
#   'Female,',
#   'Never-married,?,',
#   'Own-child,',
#   'Some-college,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '1,',
#   '241843,',
#   '40,',
#   '51,',
#   'Husband,',
#   'Local-gov,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Other-service,',
#   'Preschool,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '23,',
#   '375871,',
#   '40,',
#   '9,',
#   'Adm-clerical,',
#   'Female,',
#   'HS-grad,',
#   'Married-civ-spouse,',
#   'Mexico,',
#   'Private,',
#   'White,',
#   'Wife,'},
#  {'0,',
#   '11th,',
#   '186934,',
#   '3103,',
#   '37,',
#   '44,',
#   '7,',
#   'Husband,',
#   'Machine-op-inspct,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '176900,',
#   '37,',
#   '9,',
#   '99,',
#   'Craft-repair,',
#   'HS-grad,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '14,',
#   '21906,',
#   '25,',
#   '47,',
#   'Female,',
#   'Masters,',
#   'Never-married,',
#   'Not-in-family,',
#   'Private,',
#   'Prof-specialty,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '132222,',
#   '15,',
#   '2415,',
#   '40,',
#   '41,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'Prof-school,',
#   'Prof-specialty,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '143653,',
#   '30,',
#   '33,',
#   '9,',
#   'Craft-repair,',
#   'HS-grad,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '111567,',
#   '13,',
#   '31,',
#   '40,',
#   'Bachelors,',
#   'Male,',
#   'Never-married,',
#   'Not-in-family,',
#   'Private,',
#   'Sales,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '12,',
#   '31,',
#   '40,',
#   '78602,',
#   'Amer-Indian-Eskimo,',
#   'Assoc-acdm,',
#   'Divorced,',
#   'Female,',
#   'Other-service,',
#   'Private,',
#   'United-States,',
#   'Unmarried,'},
#  {'0,',
#   '35,',
#   '40,',
#   '465507,',
#   '9,',
#   'Black,',
#   'HS-grad,',
#   'Husband,',
#   'Machine-op-inspct,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'United-States,'},
#  {'0,',
#   '196373,',
#   '38,',
#   '40,',
#   '9,',
#   'Exec-managerial,',
#   'HS-grad,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Self-emp-inc,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '18,',
#   '293227,',
#   '45,',
#   '9,',
#   'Female,',
#   'HS-grad,',
#   'Never-married,',
#   'Not-in-family,',
#   'Other-service,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '20,',
#   '241752,',
#   '40,',
#   '9,',
#   'HS-grad,',
#   'Husband,',
#   'Machine-op-inspct,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '166398,',
#   '35,',
#   '54,',
#   'Black,',
#   'Divorced,',
#   'Exec-managerial,',
#   'Female,',
#   'Local-gov,',
#   'Some-college,',
#   'United-States,',
#   'Unmarried,'},
#  {'0,',
#   '10,',
#   '184682,',
#   '40,',
#   'Adm-clerical,',
#   'Divorced,',
#   'Female,',
#   'Private,',
#   'Some-college,',
#   'United-States,',
#   'Unmarried,',
#   'White,'},
#  {'0,',
#   '108293,',
#   '13,',
#   '1977,',
#   '36,',
#   '45,',
#   'Bachelors,',
#   'Exec-managerial,',
#   'Female,',
#   'Married-civ-spouse,',
#   'Self-emp-inc,',
#   'United-States,',
#   'White,',
#   'Wife,'},
#  {'0,',
#   '10,',
#   '250802,',
#   '35,',
#   '43,',
#   'Craft-repair,',
#   'Divorced,',
#   'Male,',
#   'Private,',
#   'Some-college,',
#   'United-States,',
#   'Unmarried,',
#   'White,'},
#  {'0,',
#   '10,',
#   '325159,',
#   '40,',
#   '44,',
#   'Divorced,',
#   'Farming-fishing,',
#   'Male,',
#   'Self-emp-not-inc,',
#   'Some-college,',
#   'United-States,',
#   'Unmarried,',
#   'White,'},
#  {'0,',
#   '174675,',
#   '40,',
#   '44,',
#   '9,',
#   'Female,',
#   'HS-grad,',
#   'Married-civ-spouse,',
#   'Prof-specialty,',
#   'State-gov,',
#   'United-States,',
#   'White,',
#   'Wife,'},
#  {'0,',
#   '14,',
#   '227065,',
#   '43,',
#   'Exec-managerial,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Masters,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '269080,',
#   '4,',
#   '40,',
#   '51,',
#   '7th-8th,',
#   'Black,',
#   'Female,',
#   'Other-service,',
#   'Private,',
#   'United-States,',
#   'Unmarried,',
#   'Widowed,'},
#  {'0,',
#   '177722,',
#   '18,',
#   '20,',
#   '9,',
#   'Female,',
#   'HS-grad,',
#   'Never-married,',
#   'Other-service,',
#   'Own-child,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '133461,',
#   '40,',
#   '51,',
#   'Exec-managerial,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'Some-college,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10th,',
#   '239683,',
#   '30,?,',
#   '41,',
#   '6,',
#   'Craft-repair,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'White,'},
#  {'0,',
#   '10,',
#   '398473,',
#   '44,',
#   '70,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Sales,',
#   'Self-emp-inc,',
#   'Some-college,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10th,',
#   '298785,',
#   '33,',
#   '40,',
#   '6,',
#   'Divorced,',
#   'Local-gov,',
#   'Male,',
#   'Not-in-family,',
#   'Transport-moving,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '123424,',
#   '13,',
#   '33,',
#   '40,',
#   'Bachelors,',
#   'Exec-managerial,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Self-emp-not-inc,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '12,',
#   '176286,',
#   '40,',
#   '42,',
#   'Assoc-acdm,',
#   'Exec-managerial,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '150062,',
#   '25,',
#   '45,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'Prof-specialty,',
#   'Some-college,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '169240,',
#   '32,',
#   '38,',
#   '9,',
#   'Divorced,',
#   'Female,',
#   'HS-grad,',
#   'Machine-op-inspct,',
#   'Not-in-family,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '13,',
#   '288273,',
#   '32,',
#   '70,',
#   'Bachelors,',
#   'Craft-repair,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Mexico,',
#   'Private,',
#   'White,'},
#  {'0,',
#   '10th,',
#   '36,',
#   '40,',
#   '526968,',
#   '6,',
#   'Divorced,',
#   'Exec-managerial,',
#   'Female,',
#   'Private,',
#   'United-States,',
#   'Unmarried,',
#   'White,'},
#  {'0,',
#   '28,',
#   '40,',
#   '57066,',
#   '9,',
#   'HS-grad,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'Transport-moving,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '20,',
#   '323573,',
#   '9,',
#   'Female,',
#   'HS-grad,',
#   'Never-married,',
#   'Other-service,',
#   'Own-child,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '35,',
#   '368825,',
#   '60,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Sales,',
#   'Self-emp-inc,',
#   'Some-college,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '189721,',
#   '20,',
#   '55,',
#   '9,',
#   'Craft-repair,',
#   'HS-grad,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Self-emp-not-inc,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '13,',
#   '164966,',
#   '40,',
#   '48,',
#   'Asian-Pac-Islander,',
#   'Bachelors,',
#   'Exec-managerial,',
#   'Husband,',
#   'India,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,'},
#  {'0,',
#   '11,',
#   '20,',
#   '36,?,',
#   '94954,',
#   'Assoc-voc,',
#   'Female,',
#   'Not-in-family,',
#   'United-States,',
#   'White,',
#   'Widowed,?,'},
#  {'0,',
#   '202046,',
#   '34,',
#   '35,',
#   '9,',
#   'Craft-repair,',
#   'HS-grad,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '13,',
#   '161538,',
#   '28,',
#   '35,',
#   'Bachelors,',
#   'Female,',
#   'Never-married,',
#   'Not-in-family,',
#   'Private,',
#   'Tech-support,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '105252,',
#   '13,',
#   '2392,',
#   '40,',
#   '67,',
#   'Bachelors,',
#   'Exec-managerial,',
#   'Male,',
#   'Not-in-family,',
#   'Private,',
#   'United-States,',
#   'White,',
#   'Widowed,'},
#  {'0,',
#   '200153,',
#   '37,',
#   '40,',
#   '9,',
#   'Craft-repair,',
#   'HS-grad,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '32185,',
#   '44,',
#   '70,',
#   '9,',
#   'HS-grad,',
#   'Male,',
#   'Never-married,',
#   'Private,',
#   'Transport-moving,',
#   'United-States,',
#   'Unmarried,',
#   'White,'},
#  {'0,',
#   '10,',
#   '178326,',
#   '25,',
#   '40,',
#   'Female,',
#   'Never-married,',
#   'Not-in-family,',
#   'Private,',
#   'Sales,',
#   'Some-college,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '10,',
#   '21,',
#   '255957,',
#   '40,',
#   '4101,',
#   'Exec-managerial,',
#   'Female,',
#   'Never-married,',
#   'Not-in-family,',
#   'Private,',
#   'Some-college,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '14,',
#   '188693,',
#   '35,',
#   '40,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Masters,',
#   'Prof-specialty,',
#   'State-gov,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '182977,',
#   '2964,',
#   '40,',
#   '78,',
#   '9,',
#   'Black,',
#   'Female,',
#   'HS-grad,',
#   'Not-in-family,',
#   'Other-service,',
#   'Private,',
#   'United-States,',
#   'Widowed,'},
#  {'0,',
#   '159929,',
#   '34,',
#   '40,',
#   '9,',
#   'Divorced,',
#   'HS-grad,',
#   'Handlers-cleaners,',
#   'Male,',
#   'Own-child,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '123207,',
#   '44,',
#   '49,',
#   '9,',
#   'Adm-clerical,',
#   'Female,',
#   'HS-grad,',
#   'Never-married,',
#   'Not-in-family,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '12,',
#   '22,',
#   '284317,',
#   '40,',
#   'Adm-clerical,',
#   'Assoc-acdm,',
#   'Female,',
#   'Never-married,',
#   'Not-in-family,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '184699,',
#   '23,?,',
#   '40,',
#   '9,',
#   'Black,',
#   'Female,',
#   'HS-grad,',
#   'Never-married,?,',
#   'United-States,',
#   'Unmarried,'},
#  {'0,',
#   '154474,',
#   '42,',
#   '60,',
#   '9,',
#   'Farming-fishing,',
#   'HS-grad,',
#   'Male,',
#   'Never-married,',
#   'Self-emp-not-inc,',
#   'United-States,',
#   'Unmarried,',
#   'White,'},
#  {'0,',
#   '318280,',
#   '40,',
#   '45,',
#   '9,',
#   'HS-grad,',
#   'Local-gov,',
#   'Male,',
#   'Not-in-family,',
#   'Protective-serv,',
#   'United-States,',
#   'White,',
#   'Widowed,'},
#  {'0,',
#   '11,',
#   '20,',
#   '254907,',
#   '63,',
#   'Assoc-voc,',
#   'Divorced,',
#   'Female,',
#   'Not-in-family,',
#   'Other-service,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '349221,',
#   '35,',
#   '41,',
#   '9,',
#   'Black,',
#   'Craft-repair,',
#   'Female,',
#   'HS-grad,',
#   'Never-married,',
#   'Own-child,',
#   'Private,',
#   'United-States,'},
#  {'0,',
#   '335973,',
#   '40,',
#   '47,',
#   '9,',
#   'Adm-clerical,',
#   'Divorced,',
#   'Female,',
#   'HS-grad,',
#   'Private,',
#   'United-States,',
#   'Unmarried,',
#   'White,'},
#  {'0,',
#   '126701,',
#   '40,',
#   '44,',
#   '9,',
#   'Craft-repair,',
#   'Divorced,',
#   'HS-grad,',
#   'Male,',
#   'Private,',
#   'United-States,',
#   'Unmarried,',
#   'White,'},
#  {'0,',
#   '10,',
#   '122159,',
#   '3325,',
#   '40,',
#   '51,',
#   'Female,',
#   'Not-in-family,',
#   'Private,',
#   'Prof-specialty,',
#   'Some-college,',
#   'United-States,',
#   'White,',
#   'Widowed,'},
#  {'0,',
#   '13,',
#   '1504,',
#   '187370,',
#   '40,',
#   '46,',
#   'Bachelors,',
#   'Male,',
#   'Never-married,',
#   'Not-in-family,',
#   'Private,',
#   'Sales,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '11,',
#   '194636,',
#   '40,',
#   '41,',
#   'Assoc-voc,',
#   'Husband,',
#   'Machine-op-inspct,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '124793,',
#   '30,',
#   '50,',
#   '9,',
#   'Craft-repair,',
#   'HS-grad,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Self-emp-not-inc,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '192835,',
#   '47,',
#   '50,',
#   '9,',
#   'Adm-clerical,',
#   'HS-grad,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '290226,',
#   '35,',
#   '45,',
#   '9,',
#   'Exec-managerial,',
#   'HS-grad,',
#   'Male,',
#   'Never-married,',
#   'Not-in-family,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '112840,',
#   '55,',
#   '56,',
#   '9,',
#   'Exec-managerial,',
#   'HS-grad,',
#   'Husband,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '14,',
#   '45,',
#   '89325,',
#   'Divorced,',
#   'Male,',
#   'Masters,',
#   'Not-in-family,',
#   'Private,',
#   'Prof-specialty,',
#   'United-States,',
#   'White,'},
#  {'0,',
#   '13,',
#   '33109,',
#   '48,',
#   '58,',
#   'Bachelors,',
#   'Divorced,',
#   'Exec-managerial,',
#   'Federal-gov,',
#   'Male,',
#   'United-States,',
#   'Unmarried,',
#   'White,'},
#  {'0,',
#   '10,',
#   '2580,',
#   '40,',
#   '82465,',
#   'Husband,',
#   'Machine-op-inspct,',
#   'Male,',
#   'Married-civ-spouse,',
#   'Private,',
#   'Some-college,',
#   'United-States,',
#   'White,'},
#  ...]

# %%
#Cette fonction prend trois arguments: un ensemble de données, Ck, une liste d'ensembles candidats et un support min, 
#qui est le support minimum qui vous intéresse. Cette fonction est utilisée pour générer L1 à partir de C1. 
#De plus, cette fonction retourne un dictionnaire avec des valeurs de support.
#C1 est un groupe d’éléments candidat de taille 1. Dans l'algorithme Apriori, nous créons C1, puis nous analysons 
#l'ensemble de données pour voir si ces ensembles d'éléments répondent à nos exigences de support minimales. 
#Les ensembles d'éléments qui répondent à nos exigences minimales deviennent L1. 
#L1 est ensuite combiné pour devenir C2 et C2 sera filtré pour devenir L2.
def scanD(D, Ck, minSupport):
    ssCnt = {}
    for tid in D:
        for can in Ck:
            if can.issubset(tid):
                if not can in ssCnt: ssCnt[can]=1
                else: ssCnt[can] += 1
    numItems = float(len(D))
    retList = []
    supportData = {}
    for key in ssCnt:
        support = ssCnt[key]/numItems
        if support >= minSupport:
            retList.insert(0,key)
        supportData[key] = support
    return retList, supportData

# %%
#La fonction aprioriGen () prendra une liste d'itemsets fréquents, Lk, et la taille des itemsets,
#k, pour produire Ck. Par exemple, les itemsets {0}, {1}, {2} et ainsi de suite seront générés {0,1} {0,2} et {1,2}.
def aprioriGen(Lk, k): #Creer Ck
    retList = []
    lenLk = len(Lk)
    for i in range(lenLk):
        for j in range(i+1, lenLk): 
            L1 = list(Lk[i])[:k-2]; L2 = list(Lk[j])[:k-2]
            L1.sort(); L2.sort()
            if L1==L2: #si k-2 premier elements sont egaux
                retList.append(Lk[i] | Lk[j]) #ajouter ensemble union
    return retList

# %%
def apriori(dataSet, minSupport = 0.5):
    C1 = createC1(dataSet)
    D = list(map(set, dataSet))
    L1, supportData = scanD(D, C1, minSupport)
    L = [L1]
    k = 2
    while (len(L[k-2]) > 0):
        Ck = aprioriGen(L[k-2], k)
        Lk, supK = scanD(D, Ck, minSupport)#balayer DB pour obtenir Lk
        supportData.update(supK)
        L.append(Lk)
        k += 1
    return L, supportData #L contient des listes de jeux d'éléments fréquents qui ont rencontré un support minimum de 0.5. 
                          #La variable suppData est un dictionnaire avec les valeurs de support de nos itemsets

# %%
#La fonction generateRules () prend trois entrées: une liste d'ensembles d'éléments fréquents, 
#un dictionnaire de données de support pour ces ensembles d'éléments et un seuil de confiance minimal. 
#Il va générer une liste de règles avec des valeurs de confiance que nous pourrons trier plus tard.
def generateRules(L, supportData, minConf=0.7):  #supportData est un dictionnaire qui vient de la fonction scanD 
    bigRuleList = []
    for i in range(1, len(L)):#n'obtenez que les ensembles contenant deux objets ou plus
        for freqSet in L[i]:
            H1 = [frozenset([item]) for item in freqSet]
            if (i > 1):
                rulesFromConseq(freqSet, H1, supportData, bigRuleList, minConf)
            else:
                calcConf(freqSet, H1, supportData, bigRuleList, minConf)
    return bigRuleList

# %%
L,suppData = apriori(dataSet)

# %%
rules= generateRules(L,suppData, minConf=0.7)
# Out:
# frozenset({'Private,'}) --> frozenset({'0,'}) conf: 1.0
# frozenset({'Private,'}) --> frozenset({'United-States,'}) conf: 0.8871607331688403
# frozenset({'Private,'}) --> frozenset({'White,'}) conf: 0.8549524145223828
# frozenset({'Male,'}) --> frozenset({'0,'}) conf: 1.0
# frozenset({'United-States,'}) --> frozenset({'0,'}) conf: 1.0
# frozenset({'0,'}) --> frozenset({'United-States,'}) conf: 0.8958570068486841
# frozenset({'Male,'}) --> frozenset({'United-States,'}) conf: 0.8943552088113815
# frozenset({'White,'}) --> frozenset({'0,'}) conf: 1.0
# frozenset({'0,'}) --> frozenset({'White,'}) conf: 0.8542735173981143
# frozenset({'Male,'}) --> frozenset({'White,'}) conf: 0.8799449288664525
# frozenset({'White,'}) --> frozenset({'United-States,'}) conf: 0.9210885821110153
# frozenset({'United-States,'}) --> frozenset({'White,'}) conf: 0.8783339046966061
# frozenset({'Private,'}) --> frozenset({'United-States,', 'White,'}) conf: 0.7811068029608742
# frozenset({'Private,'}) --> frozenset({'0,', 'White,'}) conf: 0.8549524145223828
# frozenset({'Private,'}) --> frozenset({'0,', 'United-States,'}) conf: 0.8871607331688403
# frozenset({'Male,'}) --> frozenset({'United-States,', 'White,'}) conf: 0.8101422670949977
# frozenset({'White,'}) --> frozenset({'United-States,', '0,'}) conf: 0.9210885821110153
# frozenset({'United-States,'}) --> frozenset({'0,', 'White,'}) conf: 0.8783339046966061
# frozenset({'0,'}) --> frozenset({'United-States,', 'White,'}) conf: 0.7868615828752189
# frozenset({'Male,'}) --> frozenset({'0,', 'White,'}) conf: 0.8799449288664525
# frozenset({'Male,'}) --> frozenset({'United-States,', '0,'}) conf: 0.8943552088113815
# frozenset({'Private,', '0,'}) --> frozenset({'United-States,', 'White,'}) conf: 0.7811068029608742
# frozenset({'Private,', 'White,'}) --> frozenset({'0,', 'United-States,'}) conf: 0.9136260564831994
# frozenset({'Private,', 'United-States,'}) --> frozenset({'0,', 'White,'}) conf: 0.880456915818227
# frozenset({'Private,'}) --> frozenset({'0,', 'United-States,', 'White,'}) conf: 0.7811068029608742
# frozenset({'0,', 'Male,'}) --> frozenset({'United-States,', 'White,'}) conf: 0.8101422670949977
# frozenset({'Male,', 'White,'}) --> frozenset({'0,', 'United-States,'}) conf: 0.920673829143632
# frozenset({'United-States,', 'Male,'}) --> frozenset({'0,', 'White,'}) conf: 0.9058394909688012
# frozenset({'Male,'}) --> frozenset({'0,', 'United-States,', 'White,'}) conf: 0.8101422670949977
